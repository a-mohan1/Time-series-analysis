# %% [markdown]
# # Classification of Brain Tumors using Convolutional Neural Networks #
#
# In this notebook, I implement neural network models for the classification of brain tumors. The CNNs provide better accuracy for image classification. Here, I implement both ANNs as an initial trial, and CNNs for the final implementation, and try dropout layers to reduce overfitting and improve the accuracy of prediction of the test data.

# %% [markdown]
# ## Exploratory data analysis ##
#
# In this section, the datasets are collected, preprocessed and visualized to gain an understanding of the data.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# The train and test datasets of brain tumor images are read and stored below.

# %%
# Import libraries, unzip image data

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os
import seaborn as sns

zip_path = r"/content/drive/My Drive/DS/Data_Set_BrainTumor.zip"
# !cp "{zip_path}" .
# !unzip -q Data_Set_BrainTumor.zip
# !rm Data_Set_BrainTumor.zip

# %%
#Display one image from training set

# Using Contrast Limited Adaptive Histogram Equalization
#clahe = cv2.createCLAHE()
TRAIN_DATADIR = "./Data Set Brain Tumor/Training"
CATEGORIES = ["glioma_tumor","meningioma_tumor","no_tumor","pituitary_tumor"]
for category in CATEGORIES:
    path = os.path.join(TRAIN_DATADIR,category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
        #img_array = clahe.apply(img_array) # commented out as it did not improve prediction
        plt.imshow(img_array)
        plt.show()
        plt.axis("off")
        break
    break

# %%
#Reshaping image to 150X150
IMG_SIZE = 150
new_array = cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))    
plt.imshow(new_array,cmap = "gray")
plt.axis("off")
# Out:
# (-0.5, 149.5, 149.5, -0.5)

# %%
# Function to create image data sets
# Reading the images from the path and labeling them into the given categories

def create_data(DATADIR):
    dataset = []
    for category in CATEGORIES:
        path = os.path.join(DATADIR,category)
        class_num = CATEGORIES.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
                #img_array = clahe.apply(img_array) # commented out as it did not improve prediction
                new_array = cv2.resize(img_array,(IMG_SIZE,IMG_SIZE)) 
                # normalization by minmax scaling, commented out as it did not improve results
                # normalization will be done by scaling by 255 later
                #new_array = (new_array - np.min(new_array))/(np.max(new_array)-np.min(new_array))
                dataset.append([new_array,class_num])
            except:
                pass
    return dataset

# %%
#Storing and reshaping all the training images

training_data = create_data(TRAIN_DATADIR)

# %%
#Training set, store X_train and y_train, normalize and reshape X_train

X_train = []
y_train = []
for features,label in training_data:
    X_train.append(features)
    y_train.append(label)
X_train = np.array(X_train).reshape(-1,IMG_SIZE,IMG_SIZE)
print(X_train.shape)
# normalization
X_train = X_train/255.0  
X_train = X_train.reshape(-1,IMG_SIZE,IMG_SIZE,1)
# Out:
# (2881, 150, 150)

# %% [markdown]
# Load the test images in the same way

# %%
# Load the test data
# Display the first image

TEST_DATADIR = "./Data Set Brain Tumor/Testing"

for category in CATEGORIES:
  path = os.path.join(TEST_DATADIR, category)
  for img in os.listdir(path):
    img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
    #img_array = clahe.apply(img_array) # commented out as it did not improve prediction
    plt.imshow(img_array)
    plt.show()
    plt.axis("off")
    break
  break

# %%
#Reshaping the test image to 150X150

test_array = cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))    
plt.imshow(test_array,cmap = "gray")
plt.axis("off")
# Out:
# (-0.5, 149.5, 149.5, -0.5)

# %%
#Storing and reshaping the test images
test_data = create_data(TEST_DATADIR)

# %%
#Test set, store X_test and y_test, normalize and reshape X_test

X_test = []
y_test = []

for feature, label in test_data:
  X_test.append(feature)
  y_test.append(label)

X_test = np.array(X_test).reshape(-1, IMG_SIZE, IMG_SIZE)
# normalization
X_test = X_test/255.0
X_test = X_test.reshape(-1, IMG_SIZE, IMG_SIZE, 1)
print(X_test.shape)
# Out:
# (402, 150, 150, 1)

# %%
# Import libraries

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout, InputLayer
from tensorflow.keras.layers import Input, Activation, BatchNormalization, LeakyReLU
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import losses, optimizers

# %%
# One hot encoding of target variables

y_train_e = to_categorical(y_train)
y_test_e = to_categorical(y_test)

# %%
# Target train and test data size

y_train = np.array(y_train)
y_test = np.array(y_test)

y_train.shape, y_train_e.shape, y_test.shape, y_test_e.shape
# Out:
# ((2881,), (2881, 4), (402,), (402, 4))

# %%
# Train and test data size

X_train.shape, X_test.shape
# Out:
# ((2881, 150, 150, 1), (402, 150, 150, 1))

# %%
# Size of training data set by category

train_key, train_num = np.unique(y_train, return_counts=True)
print(train_key, train_num)
# Out:
# [0 1 2 3] [829 830 395 827]

# %%
# List of Tumor category names 
Cat_names = [name.split('_')[0].capitalize() for name in CATEGORIES]
Cat_names[Cat_names.index('No')] = 'None'

# %%
# Barplot of training data by category

ax = sns.barplot(train_key, train_num, palette='rocket')
ax.set_xticklabels(Cat_names)
ax.set_yticks(np.arange(0,1000,200))
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# [<matplotlib.axis.YTick at 0x7ff1834dc080>,
#  <matplotlib.axis.YTick at 0x7ff1834d9a20>,
#  <matplotlib.axis.YTick at 0x7ff1834bdcc0>,
#  <matplotlib.axis.YTick at 0x7ff151972898>,
#  <matplotlib.axis.YTick at 0x7ff151972dd8>]

# %% [markdown]
# There are 4 categories of images (glioma_tumor, meningioma_tumor, no_tumor, and pituitary_tumor), and 829, 830, 395 and 827 images in each category in the training set. There are 2881 images in the training set in total.

# %%
# Size of test data set by category

test_key, test_num = np.unique(y_test, return_counts=True)
print(test_key, test_num)
# Out:
# [0 1 2 3] [100 115 113  74]

# %%
# Barplot of test data by category

ax = sns.barplot(test_key, test_num, palette='rocket')
ax.set_xticklabels(Cat_names)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# There are 100, 115, 113 and 74 images of each category (glioma_tumor, meningioma_tumor, no_tumor, and pituitary_tumor) in the test set. There are 402 images in all in the test set.

# %%
# Plot ten random training images

ind = np.random.randint(0, X_train.shape[0], 10)
plt.figure(figsize=(16,8))
for i, idx in enumerate(ind):
  plt.subplot(2, 5, i+1)
  plt.imshow(cv2.resize(X_train[idx], (IMG_SIZE, IMG_SIZE)), plt.cm.binary)
  plt.title(Cat_names[y_train[idx]])

# %%
# Plot 10 random test images

ind = np.random.randint(0, X_test.shape[0], 10)
plt.figure(figsize=(16,8))
for i, idx in enumerate(ind):
  plt.subplot(2, 5, i+1)
  plt.imshow(cv2.resize(X_test[idx], (IMG_SIZE, IMG_SIZE)), plt.cm.binary)
  plt.title(Cat_names[y_test[idx]])

# %%
# Plot images of each tumor category in the training set (or test set), to visualize the data by category

import itertools
# Number of images to plot in each category
nimages = 8
# Make a dataframe with images and categories
df = pd.DataFrame()
df['Images'] = [cv2.resize(X_train[idx], (IMG_SIZE, IMG_SIZE)) 
                for idx in range(X_train.shape[0])]
df['Category'] = [Cat_names[y_train[idx]] for idx in range(0, y_train.shape[0])]
# Plot
plt.figure(figsize=(16,8))
for i, j in itertools.product(range(len(Cat_names)), range(nimages)):
  img = df[df['Category']==Cat_names[i]]['Images']
  plt.subplot(4, nimages, i*nimages+j+1)
  plt.imshow(img.iloc[j], plt.cm.binary)
  plt.title(Cat_names[i])
plt.tight_layout()

# %%
# Define variables for modeling

# Number of categories
num_classes = len(CATEGORIES)
# Input shape
in_shape = X_train.shape[1:]
# Learning rate 
lr = 0.001

# %%
# Fix the seed for reproducibility, for comparing different models and hyperparameters
seed = 7
np.random.seed(seed)

# %% [markdown]
# First I try vanilla neural network models. CNN works better for the image classification in this case, but I implement the simple neural network models as a trial to check how much accuracy can be obtained.

# %% [markdown]
# ## ANN models ##

# %%
# First try a vanilla neural network model
# Flatten the input, then use Dense layers with relu acivation, 
# and the final Dense layer with softmax activation

def vanillaNN(in_shape, layers, num_classes, lr):
  i = Input(shape=in_shape)
  x = Flatten()(i)

  for nlayer, nunits in enumerate(layers):
    x = Dense(nunits)(x)
    x = Activation('relu')(x)

  x = Dense(num_classes)(x)
  x = Activation('softmax')(x)

  ann_model = Model(inputs=i, outputs=x)
  optimizer = optimizers.Adam(lr=lr)
  ann_model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
  return ann_model

# %%
# ANN with 16 and 32 units in dense layers

model_ann1 = vanillaNN(in_shape, [16,32], num_classes, lr)
model_ann1.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 150, 150, 1)]     0
# _________________________________________________________________
# flatten (Flatten)            (None, 22500)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                360016
# _________________________________________________________________
# activation (Activation)      (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                544
# _________________________________________________________________
# activation_1 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 132
# _________________________________________________________________
# activation_2 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 360,692
# Trainable params: 360,692
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Image augmentation is tried here, Since the images vary in zoom and brightness.
# Randomly generate images by brightness adjustment and zoom adjustment during training, 
# to make the classifier more robust
# Using brightness_range and zoom_range worsened the validation accuracy
# Flipping or rotation are not meaningful in this context, 
# as the images are top, side, front, or back views of the skull

from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(brightness_range=[0.9,1.1],
                             zoom_range=[0.9,1.1],
                             validation_split=0.2)

train_gen = datagen.flow(X_train, y_train_e, batch_size=128, 
                         shuffle=True, seed=42, subset='training')
val_gen = datagen.flow(X_train, y_train_e, batch_size=128, seed=42, subset='validation')

STEP_SIZE_TRAIN = train_gen.n//128
STEP_SIZE_VAL = val_gen.n//128

# %%
train_gen.n, val_gen.n # Size of training and validation data
# Out:
# (2305, 576)

# %%
# Results with image augmentation

history_model_ann1 = model_ann1.fit_generator(train_gen, validation_data=val_gen, 
                            steps_per_epoch=STEP_SIZE_TRAIN, 
                            validation_steps=STEP_SIZE_VAL,
                            epochs=40)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1
summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 150, 150, 1)]     0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 22500)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                360016
# _________________________________________________________________
# activation_3 (Activation)    (None, 16)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                544
# _________________________________________________________________
# activation_4 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 4)                 132
# _________________________________________________________________
# activation_5 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 360,692
# Trainable params: 360,692
# Non-trainable params: 0
# _________________________________________________________________

# %%
# A validation split of 0.2 and batch size of 512 are used.

history_model_ann2 = model_ann2.fit(X_train, y_train_e, 
                                    validation_split=0.2, verbose=1, 
                                    batch_size=512, epochs=40)
# Out:
# Epoch 1/40
# 5/5 [==============================] - 1s 72ms/step - loss: 1.3409 - accuracy: 0.3472 - val_loss: 1.6476 - val_accuracy: 0.1785
# Epoch 2/40
# 5/5 [==============================] - 0s 30ms/step - loss: 1.1256 - accuracy: 0.4816 - val_loss: 1.5721 - val_accuracy: 0.2756
# Epoch 3/40
# 5/5 [==============================] - 0s 29ms/step - loss: 1.0226 - accuracy: 0.5588 - val_loss: 1.5680 - val_accuracy: 0.3449
# Epoch 4/40
# 5/5 [==============================] - 2s 391ms/step - loss: 0.9636 - accuracy: 0.5767 - val_loss: 1.0510 - val_accuracy: 0.7071
# Epoch 5/40
# 5/5 [==============================] - 0s 30ms/step - loss: 0.8863 - accuracy: 0.6407 - val_loss: 1.1600 - val_accuracy: 0.5789
# Epoch 6/40
# 5/5 [==============================] - 0s 31ms/step - loss: 0.8237 - accuracy: 0.6752 - val_loss: 0.9691 - val_accuracy: 0.6898
# Epoch 7/40
# 5/5 [==============================] - 0s 31ms/step - loss: 0.7971 - accuracy: 0.6956 - val_loss: 1.2421 - val_accuracy: 0.5147
# Epoch 8/40
# 5/5 [==============================] - 0s 31ms/step - loss: 0.7627 - accuracy: 0.6935 - val_loss: 0.7317 - val_accuracy: 0.8146
# Epoch 9/40
# 5/5 [==============================] - 0s 30ms/step - loss: 0.7378 - accuracy: 0.7005 - val_loss: 1.0373 - val_accuracy: 0.6430
# Epoch 10/40
# 5/5 [==============================] - 0s 29ms/step - loss: 0.6980 - accuracy: 0.7293 - val_loss: 0.7311 - val_accuracy: 0.7903
# Epoch 11/40
# 5/5 [==============================] - 0s 30ms/step - loss: 0.6594 - accuracy: 0.7489 - val_loss: 1.0586 - val_accuracy: 0.6031
# Epoch 12/40
# 5/5 [==============================] - 0s 30ms/step - loss: 0.6376 - accuracy: 0.7610 - val_loss: 0.6347 - val_accuracy: 0.8267
# Epoch 13/40
# 5/5 [==============================] - 0s 29ms/step - loss: 0.6215 - accuracy: 0.7717 - val_loss: 0.9835 - val_accuracy: 0.6326
# Epoch 14/40
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5860 - accuracy: 0.7952 - val_loss: 0.6353 - val_accuracy: 0.8267
# Epoch 15/40
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5692 - accuracy: 0.8030 - val_loss: 0.8179 - val_accuracy: 0.7418
# Epoch 16/40
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5853 - accuracy: 0.7685 - val_loss: 0.6676 - val_accuracy: 0.8007
# Epoch 17/40
# 5/5 [==============================] - 0s 31ms/step - loss: 0.5409 - accuracy: 0.7987 - val_loss: 0.6620 - val_accuracy: 0.8007
# Epoch 18/40
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5266 - accuracy: 0.8058 - val_loss: 0.7994 - val_accuracy: 0.7331
# Epoch 19/40
# 5/5 [==============================] - 0s 29ms/step - loss: 0.4972 - accuracy: 0.8411 - val_loss: 0.5743 - val_accuracy: 0.8388
# Epoch 20/40
# 5/5 [==============================] - 0s 30ms/step - loss: 0.4867 - accuracy: 0.8435 - val_loss: 0.7995 - val_accuracy: 0.7279
# Epoch 21/40
# 5/5 [==============================] - 0s 31ms/step - loss: 0.4815 - accuracy: 0.8396 - val_loss: 0.5322 - val_accuracy: 0.8648
# Epoch 22/40
# 5/5 [==============================] - 0s 30ms/step - loss: 0.4735 - accuracy: 0.8288 - val_loss: 0.8835 - val_accuracy: 0.7002
# Epoch 23/40
# 5/5 [==============================] - 0s 29ms/step - loss: 0.4672 - accuracy: 0.8374 - val_loss: 0.7093 - val_accuracy: 0.7764
# Epoch 24/40
# 5/5 [==============================] - 0s 30ms/step - loss: 0.4513 - accuracy: 0.8533 - val_loss: 0.6929 - val_accuracy: 0.7972
# Epoch 25/40
# 5/5 [==============================] - 0s 30ms/step - loss: 0.4238 - accuracy: 0.8693 - val_loss: 0.5352 - val_accuracy: 0.8544
# Epoch 26/40
# 5/5 [==============================] - 0s 30ms/step - loss: 0.4167 - accuracy: 0.8709 - val_loss: 0.5724 - val_accuracy: 0.8371
# Epoch 27/40
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3838 - accuracy: 0.8838 - val_loss: 0.5705 - val_accuracy: 0.8354
# Epoch 28/40
# 5/5 [==============================] - 0s 32ms/step - loss: 0.3798 - accuracy: 0.8912 - val_loss: 0.6726 - val_accuracy: 0.8007
# Epoch 29/40
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3650 - accuracy: 0.9008 - val_loss: 0.5464 - val_accuracy: 0.8648
# Epoch 30/40
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3622 - accuracy: 0.9008 - val_loss: 0.6351 - val_accuracy: 0.8042
# Epoch 31/40
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3576 - accuracy: 0.9008 - val_loss: 0.4431 - val_accuracy: 0.8977
# Epoch 32/40
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3425 - accuracy: 0.9031 - val_loss: 0.7538 - val_accuracy: 0.7626
# Epoch 33/40
# 5/5 [==============================] - 0s 32ms/step - loss: 0.3313 - accuracy: 0.9109 - val_loss: 0.4701 - val_accuracy: 0.8856
# Epoch 34/40
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3115 - accuracy: 0.9239 - val_loss: 0.7730 - val_accuracy: 0.7348
# Epoch 35/40
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3161 - accuracy: 0.9206 - val_loss: 0.4733 - val_accuracy: 0.8873
# Epoch 36/40
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3078 - accuracy: 0.9234 - val_loss: 0.5097 - val_accuracy: 0.8752
# Epoch 37/40
# 5/5 [==============================] - 0s 31ms/step - loss: 0.3090 - accuracy: 0.9152 - val_loss: 0.6304 - val_accuracy: 0.8198
# Epoch 38/40
# 5/5 [==============================] - 0s 31ms/step - loss: 0.3374 - accuracy: 0.8804 - val_loss: 0.5426 - val_accuracy: 0.8510
# Epoch 39/40
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2954 - accuracy: 0.9183 - val_loss: 0.5611 - val_accuracy: 0.8302
# Epoch 40/40
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2845 - accuracy: 0.9112 - val_loss: 0.4914 - val_accuracy: 0.8579

# %% [markdown]
# The ANN model fit without image augmentation performs better than the fit using image augmentation. However, since the convolutional neural networks are expected to perform better for this image classification problem, the CNN models are tried next.

# %% [markdown]
# The function to plot accuracy and loss is defined below.

# %%
# Plot results
# Function to plot accuracy and loss

def plot_acc(dict_hist, iepoch):
  fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,4))
  ax1.plot(iepoch, dict_hist['accuracy'], '-r', label='Training Accuracy')
  ax1.plot(iepoch, dict_hist['val_accuracy'], '--b', label='Validation Accuracy')
  ax1.legend()
  ax1.set_xlabel('Epoch')
  ax1.set_ylabel('Accuracy')
  ax2.plot(iepoch, dict_hist['loss'], '-r', label='Training Loss')
  ax2.plot(iepoch, dict_hist['val_loss'], '--b', label='Validation Loss')
  ax2.legend()
  ax2.set_xlabel('Epoch')
  ax2.set_ylabel('Loss')
  plt.show()

# %%
# Plot results for ANN

dict_hist_ann2 = history_model_ann2.history
iepoch = np.arange(1,41)
plot_acc(dict_hist_ann2, iepoch)

# %% [markdown]
# ## CNN models ##

# %%
# Build a CNN
# Conv2D and LeakyReLU layers, followed by MaxPool2D, Flatten, 
# fully connected Dense layer with LeakyReLU,
# and final Dense layer with softmax activation
# A kernel size of 3 is used
# A slope of 0.1 for LeakyReLU is used.

# Function with default parameters
def convNN(in_shape=in_shape, layers=[8,16], ndense=16, num_classes=num_classes, 
           lr=0.001):
  i = Input(shape=in_shape)
  kernel_size = 3
  leakyrelu_slope = 0.1

  for nlayer, nfilters in enumerate(layers):
    if (nlayer==0):
      x = Conv2D(nfilters, kernel_size=kernel_size, padding='same')(i)
    else:
      x = Conv2D(nfilters, kernel_size=kernel_size, padding='same')(x)
    x = LeakyReLU(leakyrelu_slope)(x)

  x = MaxPool2D(pool_size=2)(x)
  x = Flatten()(x)
  x = Dense(ndense)(x)
  x = LeakyReLU(leakyrelu_slope)(x)
  x = Dense(num_classes, activation='softmax')(x)

  model_cnn = Model(inputs=i, outputs=x)
  adam = optimizers.Adam(lr=lr)
  model_cnn.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

  return model_cnn

# %%
# CNN with 16 and 32 filters in Conv2D layers, and 32 units in fully connected dense layer
lr = 0.001

model_cnn1 = convNN(in_shape, [16,32], 32, num_classes, lr)

# %%
model_cnn1.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 150, 150, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 150, 150, 16)      160
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 150, 150, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 32)      4640
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 150, 150, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 180000)            0
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                5760032
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 32)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 5,764,964
# Trainable params: 5,764,964
# Non-trainable params: 0
# _________________________________________________________________

# %%
# CNN is fit with image augmentation. It does not perform well with image augmentation.

history_model_cnn1 = model_cnn1.fit(train_gen, validation_data=val_gen,
                                    steps_per_epoch=STEP_SIZE_TRAIN,
                                    validation_steps=STEP_SIZE_VAL,
                                    epochs=40)
# Out:
# Epoch 1/40
# 18/18 [==============================] - 6s 338ms/step - loss: 432.5375 - accuracy: 0.3779 - val_loss: 10.3663 - val_accuracy: 0.5215
# Epoch 2/40
# 18/18 [==============================] - 6s 316ms/step - loss: 20.7084 - accuracy: 0.5423 - val_loss: 3.0708 - val_accuracy: 0.7441
# Epoch 3/40
# 18/18 [==============================] - 6s 315ms/step - loss: 3.7671 - accuracy: 0.6379 - val_loss: 3.5568 - val_accuracy: 0.3457
# Epoch 4/40
# 18/18 [==============================] - 6s 317ms/step - loss: 2.2899 - accuracy: 0.6862 - val_loss: 2.3712 - val_accuracy: 0.5703
# Epoch 5/40
# 18/18 [==============================] - 6s 316ms/step - loss: 1.9471 - accuracy: 0.6839 - val_loss: 1.7959 - val_accuracy: 0.5820
# Epoch 6/40
# 18/18 [==============================] - 6s 315ms/step - loss: 1.3129 - accuracy: 0.7261 - val_loss: 3.9272 - val_accuracy: 0.2676
# Epoch 7/40
# Epoch 27/40
# 18/18 [==============================] - 6s 314ms/step - loss: 0.2861 - accuracy: 0.9001 - val_loss: 1.4078 - val_accuracy: 0.6055
# Epoch 28/40
# 18/18 [==============================] - 6s 316ms/step - loss: 0.2944 - accuracy: 0.9033 - val_loss: 2.2963 - val_accuracy: 0.4570
# Epoch 29/40
# 18/18 [==============================] - 6s 318ms/step - loss: 0.2687 - accuracy: 0.9042 - val_loss: 2.0683 - val_accuracy: 0.4844
# Epoch 30/40
# 18/18 [==============================] - 6s 317ms/step - loss: 0.1871 - accuracy: 0.9357 - val_loss: 1.4489 - val_accuracy: 0.5801
# Epoch 31/40
# 18/18 [==============================] - 6s 316ms/step - loss: 0.2029 - accuracy: 0.9306 - val_loss: 1.6846 - val_accuracy: 0.5645
# Epoch 32/40
# 18/18 [==============================] - 6s 319ms/step - loss: 0.2280 - accuracy: 0.9177 - val_loss: 1.0313 - val_accuracy: 0.7188
# Epoch 33/40
# 18/18 [==============================] - 6s 321ms/step - loss: 1.3262 - accuracy: 0.8225 - val_loss: 4.2056 - val_accuracy: 0.2148
# Epoch 34/40
# 18/18 [==============================] - 6s 316ms/step - loss: 1.4119 - accuracy: 0.7807 - val_loss: 4.0634 - val_accuracy: 0.2637
# Epoch 35/40
# 18/18 [==============================] - 6s 317ms/step - loss: 0.6118 - accuracy: 0.8641 - val_loss: 2.1719 - val_accuracy: 0.5000
# Epoch 36/40
# 18/18 [==============================] - 6s 317ms/step - loss: 0.4133 - accuracy: 0.9024 - val_loss: 1.3829 - val_accuracy: 0.6426
# Epoch 37/40
# 18/18 [==============================] - 6s 310ms/step - loss: 0.3594 - accuracy: 0.9060 - val_loss: 1.9181 - val_accuracy: 0.5508
# Epoch 38/40
# 18/18 [==============================] - 6s 313ms/step - loss: 0.2257 - accuracy: 0.9415 - val_loss: 1.6180 - val_accuracy: 0.6152
# Epoch 39/40
# 18/18 [==============================] - 6s 311ms/step - loss: 0.2052 - accuracy: 0.9313 - val_loss: 1.9696 - val_accuracy: 0.4980
# Epoch 40/40
# 18/18 [==============================] - 6s 319ms/step - loss: 0.1969 - accuracy: 0.9402 - val_loss: 1.9646 - val_accuracy: 0.5254

# %%
# Plot results
# The CNN model with image augmentation does not perform well

dict_hist_cnn1 = history_model_cnn1.history
iepoch = np.arange(1, 41)
plot_acc(dict_hist_cnn1, iepoch)

# %% [markdown]
# Since image augmentation does not give good results, it will not be used here.

# %%
# CNN model without image generator
# CNN with 16 and 32 filters in Conv2D layers, and 32 units in fully connected dense layer
lr = 0.001

model_cnn2 = convNN(in_shape, [16,32], 32, num_classes, lr)

# %%
history_model_cnn2= model_cnn2.fit(X_train, y_train_e, validation_split=0.2, 
                                   verbose=1, batch_size=256, epochs=40)
# Out:
# Epoch 1/40
# 9/9 [==============================] - 1s 86ms/step - loss: 1.6286 - accuracy: 0.3137 - val_loss: 1.2942 - val_accuracy: 0.4298
# Epoch 2/40
# 9/9 [==============================] - 1s 64ms/step - loss: 0.9493 - accuracy: 0.5640 - val_loss: 0.6913 - val_accuracy: 0.8094
ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5393 - val_accuracy: 0.9133
# Epoch 32/40
# 9/9 [==============================] - 1s 64ms/step - loss: 9.6587e-04 - accuracy: 1.0000 - val_loss: 0.5465 - val_accuracy: 0.9133
# Epoch 33/40
# 9/9 [==============================] - 1s 63ms/step - loss: 9.1160e-04 - accuracy: 1.0000 - val_loss: 0.5258 - val_accuracy: 0.9168
# Epoch 34/40
# 9/9 [==============================] - 1s 63ms/step - loss: 8.4044e-04 - accuracy: 1.0000 - val_loss: 0.5485 - val_accuracy: 0.9133
# Epoch 35/40
# 9/9 [==============================] - 1s 63ms/step - loss: 8.3728e-04 - accuracy: 1.0000 - val_loss: 0.5532 - val_accuracy: 0.9133
# Epoch 36/40
# 9/9 [==============================] - 1s 62ms/step - loss: 7.6598e-04 - accuracy: 1.0000 - val_loss: 0.5456 - val_accuracy: 0.9168
# Epoch 37/40
# 9/9 [==============================] - 1s 64ms/step - loss: 7.5311e-04 - accuracy: 1.0000 - val_loss: 0.5382 - val_accuracy: 0.9168
# Epoch 38/40
# 9/9 [==============================] - 1s 64ms/step - loss: 7.0146e-04 - accuracy: 1.0000 - val_loss: 0.5541 - val_accuracy: 0.9133
# Epoch 39/40
# 9/9 [==============================] - 1s 63ms/step - loss: 6.6522e-04 - accuracy: 1.0000 - val_loss: 0.5558 - val_accuracy: 0.9151
# Epoch 40/40
# 9/9 [==============================] - 1s 63ms/step - loss: 6.0963e-04 - accuracy: 1.0000 - val_loss: 0.5642 - val_accuracy: 0.9151

# %%
# Plotting the accuracy and loss

dict_hist_cnn2 = history_model_cnn2.history
iepoch = [i for i in range(1,41)]

plot_acc(dict_hist_cnn2, iepoch)

# %% [markdown]
# The above CNN model performs better without image augmentation, but is overfitting. A CNN model with fewer filters is tried below.

# %%
# CNN model with fewer filters
# CNN with 8 and 16 filters in Conv2D layers, and 16 units in fully connected dense layer
lr = 0.001

model_cnn3 = convNN(in_shape, [8,16], 16, num_classes, lr)

model_cnn3.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 150, 150, 1)]     0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 150, 150, 8)       80
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 150, 150, 8)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 150, 150, 16)      1168
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 150, 150, 16)      0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 75, 75, 16)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 90000)             0
# _________________________________________________________________
# dense_11 (Dense)             (None, 16)                1440016
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 16)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 4)                 68
# =================================================================
# Total params: 1,441,332
# Trainable params: 1,441,332
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_model_cnn3 = model_cnn3.fit(X_train, y_train_e, validation_split=0.2, 
                                   verbose=1, batch_size=512, epochs=40)
# Out:
# Epoch 1/40
# 5/5 [==============================] - 1s 118ms/step - loss: 1.3689 - accuracy: 0.3255 - val_loss: 1.6488 - val_accuracy: 0.0000e+00
# Epoch 2/40
# 5/5 [==============================] - 0s 75ms/step - loss: 1.1298 - accuracy: 0.4471 - val_loss: 1.5940 - val_accuracy: 0.0953
# Epoch 3/40
# 5/5 [==============================] - 0s 74ms/step - loss: 0.9589 - accuracy: 0.5382 - val_loss: 1.1821 - val_accuracy: 0.5737
# Epoch 4/40
# 5/5 [==============================] - 0s 74ms/step - loss: 0.8509 - accuracy: 0.6305 - val_loss: 1.3259 - val_accuracy: 0.4073
# Epoch 5/40
# 5/5 [==============================] - 0s 75ms/step - loss: 0.7549 - accuracy: 0.6639 - val_loss: 1.1697 - val_accuracy: 0.5095
# Epoch 6/40
# 5/5 [==============================] - 0s 74ms/step - loss: 0.6715 - accuracy: 0.7020 - val_loss: 0.9160 - val_accuracy: 0.7019
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0569 - accuracy: 0.9937 - val_loss: 0.2907 - val_accuracy: 0.9411
# Epoch 32/40
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0557 - accuracy: 0.9923 - val_loss: 0.3202 - val_accuracy: 0.9341
# Epoch 33/40
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0455 - accuracy: 0.9946 - val_loss: 0.2803 - val_accuracy: 0.9480
# Epoch 34/40
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0385 - accuracy: 0.9986 - val_loss: 0.3068 - val_accuracy: 0.9411
# Epoch 35/40
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0422 - accuracy: 0.9960 - val_loss: 0.2894 - val_accuracy: 0.9445
# Epoch 36/40
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0358 - accuracy: 0.9982 - val_loss: 0.3045 - val_accuracy: 0.9341
# Epoch 37/40
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0313 - accuracy: 0.9991 - val_loss: 0.3338 - val_accuracy: 0.9324
# Epoch 38/40
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0294 - accuracy: 0.9989 - val_loss: 0.2707 - val_accuracy: 0.9515
# Epoch 39/40
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0296 - accuracy: 0.9988 - val_loss: 0.2874 - val_accuracy: 0.9480
# Epoch 40/40
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0257 - accuracy: 0.9999 - val_loss: 0.3561 - val_accuracy: 0.9307

# %%
# Plot results

dict_hist_cnn3 = history_model_cnn3.history
iepoch = np.arange(1,41)
plot_acc(dict_hist_cnn3, iepoch)

# %% [markdown]
# Dropout layers are added below to reduce overfitting and make the model generalize better.

# %% [markdown]
# ## CNN with Dropout ##

# %%
# Build a CNN with Dropout layers to prevent overfitting
# Conv2D, LeakyReLU and Dropout layers, 
# Followed by MaxPool2D, Flatten, and fully connected Dense layers with LeakyReLU and Dropout
# and final output Dense layer
# Using pool_size of 2

def ConvNNdo(in_shape, layers, kernelsize, ndense, num_classes, lr):

  leakyrelu_slope = 0.1
  # Dropout fraction for conv layers
  dropout1 = 0.2
  # Dropout fraction for dense layer
  # Dropout fraction of 0.2 was also tried, but increased to 0.5 to reduce overfitting
  dropout2 = 0.5

  i = Input(shape=in_shape)

  for nlayer, nfilters in enumerate(layers):
    if (nlayer==0):
      x = Conv2D(nfilters, kernel_size=kernelsize, padding='same')(i)
    else:
      x = Conv2D(nfilters, kernel_size=kernelsize, padding='same')(x)
    x = LeakyReLU(leakyrelu_slope)(x)
    x = Dropout(dropout1)(x)

  x = MaxPool2D(pool_size=2)(x)
  x = Flatten()(x)
  x = Dense(ndense)(x)
  x = LeakyReLU(leakyrelu_slope)(x)
  x = Dropout(dropout2)(x)
  x = Dense(num_classes, activation='softmax')(x)

  model_cnndo = Model(inputs=i, outputs=x)

  adam = optimizers.Adam(lr=lr)
  model_cnndo.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

  return model_cnndo

# %%
# Conv layers with [8,16,32,16,8] filters
# Dense layer with 32 units

kernelsize = 3
model_cnndo1 = ConvNNdo(in_shape, [8,16,32,16,8], kernelsize, 32, num_classes, lr)
model_cnndo1.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 150, 150, 1)]     0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 150, 150, 8)       80
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 150, 150, 8)       0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 150, 150, 8)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 150, 150, 16)      1168
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 150, 150, 16)      0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 150, 150, 16)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 150, 150, 32)      4640
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 150, 150, 32)      0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 150, 150, 32)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 150, 150, 16)      4624
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 150, 150, 16)      0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 150, 150, 16)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 150, 150, 8)       1160
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 150, 150, 8)       0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 150, 150, 8)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 75, 75, 8)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 45000)             0
# _________________________________________________________________
# dense_13 (Dense)             (None, 32)                1440032
# _________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)   (None, 32)                0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 1,451,836
# Trainable params: 1,451,836
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_model_cnndo1 = model_cnndo1.fit(X_train, y_train_e, 
                                        validation_split=0.2,
                                        verbose=1, batch_size=128, 
                                        shuffle=True, epochs=40)
# Out:
# Epoch 1/40
# 18/18 [==============================] - 8s 113ms/step - loss: 1.4391 - accuracy: 0.3705 - val_loss: 1.5592 - val_accuracy: 0.0000e+00
# Epoch 2/40
# 18/18 [==============================] - 1s 83ms/step - loss: 1.1740 - accuracy: 0.4622 - val_loss: 1.1723 - val_accuracy: 0.5633
# Epoch 3/40
# 18/18 [==============================] - 1s 82ms/step - loss: 1.0315 - accuracy: 0.5230 - val_loss: 0.5481 - val_accuracy: 0.8804
# Epoch 4/40
# 18/18 [==============================] - 1s 83ms/step - loss: 0.8794 - accuracy: 0.6121 - val_loss: 0.5019 - val_accuracy: 0.8059
# Epoch 5/40
# 18/18 [==============================] - 1s 82ms/step - loss: 0.7147 - accuracy: 0.7083 - val_loss: 0.6757 - val_accuracy: 0.7192
# Epoch 6/40
# 18/18 [==============================] - 1s 83ms/step - loss: 0.6592 - accuracy: 0.7297 - val_loss: 0.4047 - val_accuracy: 0.8510
# Epoch 7/40
# 18/18 [==============================] - 1s 82ms/step - loss: 0.5103 - accuracy: 0.7738 - val_loss: 0.6017 - val_accuracy: 0.7591
# Epoch 8/40
# 18/18 [==============================] - 2s 92ms/step - loss: 0.4125 - accuracy: 0.8383 - val_loss: 0.4666 - val_accuracy: 0.8319
# Epoch 9/40
# 18/18 [==============================] - 1s 82ms/step - loss: 0.3686 - accuracy: 0.8531 - val_loss: 0.4598 - val_accuracy: 0.8388
# Epoch 10/40
# 18/18 [==============================] - 1s 82ms/step - loss: 0.3522 - accuracy: 0.8631 - val_loss: 0.4513 - val_accuracy: 0.8475
# Epoch 11/40
# 18/18 [==============================] - 1s 82ms/step - loss: 0.3193 - accuracy: 0.8720 - val_loss: 0.3222 - val_accuracy: 0.8908
# Epoch 12/40
# 18/18 [==============================] - 1s 82ms/step - loss: 0.2455 - accuracy: 0.9052 - val_loss: 0.2783 - val_accuracy: 0.8839
# Epoch 13/40
# 18/18 [==============================] - 1s 83ms/step - loss: 0.2692 - accuracy: 0.9010 - val_loss: 0.3378 - val_accuracy: 0.8839
# Epoch 14/40
# 18/18 [==============================] - 1s 83ms/step - loss: 0.1862 - accuracy: 0.9189 - val_loss: 0.2402 - val_accuracy: 0.9151
# Epoch 15/40
# 18/18 [==============================] - 1s 82ms/step - loss: 0.1868 - accuracy: 0.9263 - val_loss: 0.3331 - val_accuracy: 0.8995
# Epoch 16/40
# 18/18 [==============================] - 1s 83ms/step - loss: 0.1597 - accuracy: 0.9385 - val_loss: 0.3855 - val_accuracy: 0.8943
# Epoch 17/40
# 18/18 [==============================] - 1s 83ms/step - loss: 0.1559 - accuracy: 0.9356 - val_loss: 0.2250 - val_accuracy: 0.9289
# Epoch 18/40
# 18/18 [==============================] - 1s 83ms/step - loss: 0.1328 - accuracy: 0.9426 - val_loss: 0.2861 - val_accuracy: 0.9272
# Epoch 19/40
# 18/18 [==============================] - 1s 82ms/step - loss: 0.1360 - accuracy: 0.9581 - val_loss: 0.2180 - val_accuracy: 0.9411
# Epoch 20/40
# 18/18 [==============================] - 1s 83ms/step - loss: 0.1143 - accuracy: 0.9600 - val_loss: 0.2308 - val_accuracy: 0.9445
# Epoch 21/40
# 18/18 [==============================] - 1s 83ms/step - loss: 0.1341 - accuracy: 0.9439 - val_loss: 0.2826 - val_accuracy: 0.9341
# Epoch 22/40
# 18/18 [==============================] - 1s 82ms/step - loss: 0.1159 - accuracy: 0.9569 - val_loss: 0.5515 - val_accuracy: 0.8925
# Epoch 23/40
# 18/18 [==============================] - 1s 82ms/step - loss: 0.1050 - accuracy: 0.9595 - val_loss: 0.4211 - val_accuracy: 0.9081
# Epoch 24/40
# 18/18 [==============================] - 1s 82ms/step - loss: 0.1364 - accuracy: 0.9469 - val_loss: 0.2942 - val_accuracy: 0.9445
# Epoch 25/40
# 18/18 [==============================] - 1s 82ms/step - loss: 0.1122 - accuracy: 0.9622 - val_loss: 0.2736 - val_accuracy: 0.9480
# Epoch 26/40
# 18/18 [==============================] - 1s 83ms/step - loss: 0.0914 - accuracy: 0.9680 - val_loss: 0.3545 - val_accuracy: 0.9341
# Epoch 27/40
# 18/18 [==============================] - 1s 83ms/step - loss: 0.1036 - accuracy: 0.9668 - val_loss: 0.3010 - val_accuracy: 0.9463
# Epoch 28/40
# 18/18 [==============================] - 1s 83ms/step - loss: 0.0942 - accuracy: 0.9635 - val_loss: 0.3447 - val_accuracy: 0.9393
# Epoch 29/40
# 18/18 [==============================] - 1s 83ms/step - loss: 0.0932 - accuracy: 0.9662 - val_loss: 0.3375 - val_accuracy: 0.9289
# Epoch 30/40
# 18/18 [==============================] - 1s 83ms/step - loss: 0.0705 - accuracy: 0.9699 - val_loss: 0.3675 - val_accuracy: 0.9445
# Epoch 31/40
# 18/18 [==============================] - 1s 83ms/step - loss: 0.0540 - accuracy: 0.9794 - val_loss: 0.4023 - val_accuracy: 0.9341
# Epoch 32/40
# 18/18 [==============================] - 1s 83ms/step - loss: 0.0547 - accuracy: 0.9772 - val_loss: 0.4214 - val_accuracy: 0.9341
# Epoch 33/40
# 18/18 [==============================] - 1s 83ms/step - loss: 0.0719 - accuracy: 0.9734 - val_loss: 0.3549 - val_accuracy: 0.9289
# Epoch 34/40
# 18/18 [==============================] - 1s 82ms/step - loss: 0.0731 - accuracy: 0.9756 - val_loss: 0.4541 - val_accuracy: 0.9307
# Epoch 35/40
# 18/18 [==============================] - 1s 82ms/step - loss: 0.0477 - accuracy: 0.9844 - val_loss: 0.4329 - val_accuracy: 0.9324
# Epoch 36/40
# 18/18 [==============================] - 1s 83ms/step - loss: 0.0645 - accuracy: 0.9742 - val_loss: 0.5565 - val_accuracy: 0.9047
# Epoch 37/40
# 18/18 [==============================] - 1s 83ms/step - loss: 0.0596 - accuracy: 0.9806 - val_loss: 0.4462 - val_accuracy: 0.9359
# Epoch 38/40
# 18/18 [==============================] - 1s 82ms/step - loss: 0.0544 - accuracy: 0.9801 - val_loss: 0.4111 - val_accuracy: 0.9341
# Epoch 39/40
# 18/18 [==============================] - 1s 82ms/step - loss: 0.0572 - accuracy: 0.9775 - val_loss: 0.3778 - val_accuracy: 0.9359
# Epoch 40/40
# 18/18 [==============================] - 1s 82ms/step - loss: 0.0602 - accuracy: 0.9775 - val_loss: 0.4139 - val_accuracy: 0.9411

# %%
# Results 

dict_hist_cnndo1 = history_model_cnndo1.history
iepoch = np.arange(1,41)
plot_acc(dict_hist_cnndo1, iepoch)

# %% [markdown]
# * This model did not improve performance.
# * The loss plot shows that there is overfitting after about epoch 20.
#
# Other hyperparameters were tried, as shown below:
# * Kernel size of 3 or 5 was tried.
# * 2 to 5 Conv layers with filters of 8, 16, 32.
# * Dense layer with units of 8, 16, 32, or 256.

# %% [markdown]
# ## LeNet-5-type architecture ##

# %% [markdown]
# Below, the LeNet-5-type architecture is tried. This is set up with two convolutional layers with leaky relu, each followed by max pooling, and two fully connected dense layers with leaky relu activation. Dropout or batch normalization are added to reduce overfitting.

# %%
# LeNet-5-type architecture
# Conv2D, MaxPool2D 2X2 layers
# Dense layers
# Output layer
# Optional Dropout or Batch Normalization after Conv and Dense layers

class conv_Layers:

  def __init__(self, nfilters, kernel_size, stride=1, 
               pool_size=2, leakyrelu_slope=0.1, dropc=0.0, bnorm=False):
    self.nfilters = nfilters
    self.kernel_size = kernel_size
    self.stride = stride
    self.pool_size = pool_size
    self.leakyrelu_slope = leakyrelu_slope
    self.dropfrac = dropc
    self.bnorm = bnorm
  
  def __call__(self, x):
    x = Conv2D(self.nfilters, kernel_size=self.kernel_size, 
               strides=self.stride, padding='same')(x)
    x = LeakyReLU(self.leakyrelu_slope)(x)
    if (self.dropfrac > 0.0): 
      x = Dropout(self.dropfrac)(x)
    if (self.bnorm):
      x = BatchNormalization()(x)
    x = MaxPool2D(self.pool_size)(x)
    return x

class dense_Layers:

  def __init__(self, nunits, leakyrelu_slope=0.1, dropd=0.0, bnorm=False):
    self.nunits = nunits
    self.leakyrelu_slope = leakyrelu_slope 
    self.dropfrac = dropd
    self.bnorm = bnorm

  def __call__(self, x):
    x = Dense(self.nunits)(x)
    x = LeakyReLU(self.leakyrelu_slope)(x)
    if (self.dropfrac > 0.0):
      x = Dropout(self.dropfrac)(x)
    if (self.bnorm):
      x = BatchNormalization()(x)
    return x

def LNmodel(in_shape, conv_filters, dense_filters, kernel_size, num_classes, lr,
            stride=1, pool_size=2, leakyrelu_slope=0.1, dropc=0.0, dropd=0.0, bnorm=False):

  i = Input(shape=in_shape)
  for ncl, nconvfilters in enumerate(conv_filters):
    if (ncl==0):
      x = conv_Layers(nconvfilters, kernel_size,
                      stride, pool_size, leakyrelu_slope, dropc, bnorm)(i)
    else:
      x = conv_Layers(nconvfilters, kernel_size,
                      stride, pool_size, leakyrelu_slope, dropc, bnorm)(x)

  x = Flatten()(x)

  for ndl, ndunits in enumerate(dense_filters):
    x = dense_Layers(ndunits, leakyrelu_slope, dropd, bnorm)(x)

  x = Dense(num_classes, activation='softmax')(x)

  ln_model  = Model(inputs=i, outputs=x)
  adam = optimizers.Adam(lr=lr)
  ln_model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
  return ln_model

# %%
# Conv2D 8 filters 5X5, MaxPool2D 2X2, Conv2D 16 filters 5X5, MaxPool2D, 2X2
# 2 Dense layers 16, 8 units
# With Dropout after conv and dense layers
# Dropout fraction of 0.25 after conv layers, 0.5 after dense layers 
# (dropout fraction of 0.2 was attempted, but higher dropout fraction performed better)

lr = 0.001
kernelsize = 5
model_ln1 = LNmodel(in_shape, [8,16], [16,8], kernelsize, num_classes, lr,
                    stride=1, pool_size=2, leakyrelu_slope=0.1, dropc=0.25, 
                    dropd=0.5, bnorm=False)
model_ln1.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 150, 150, 1)]     0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 150, 150, 8)       208
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 150, 150, 8)       0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 150, 150, 8)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 75, 75, 8)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 75, 75, 16)        3216
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 75, 75, 16)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 75, 75, 16)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 37, 37, 16)        0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 21904)             0
# _________________________________________________________________
# dense_15 (Dense)             (None, 16)                350480
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 16)                0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 8)                 136
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 8)                 0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_17 (Dense)             (None, 4)                 36
# =================================================================
# Total params: 354,076
# Trainable params: 354,076
# Non-trainable params: 0
# _________________________________________________________________

# %%
history
40
# 9/9 [==============================] - 0s 38ms/step - loss: 0.8224 - accuracy: 0.6616 - val_loss: 0.8826 - val_accuracy: 0.8232
# Epoch 22/40
# 9/9 [==============================] - 0s 38ms/step - loss: 0.7923 - accuracy: 0.6818 - val_loss: 0.9270 - val_accuracy: 0.7123
# Epoch 23/40
# 9/9 [==============================] - 0s 39ms/step - loss: 0.7589 - accuracy: 0.6912 - val_loss: 0.8017 - val_accuracy: 0.8769
# Epoch 24/40
# 9/9 [==============================] - 0s 38ms/step - loss: 0.7686 - accuracy: 0.7003 - val_loss: 1.1186 - val_accuracy: 0.6291
# Epoch 25/40
# 9/9 [==============================] - 0s 38ms/step - loss: 0.7365 - accuracy: 0.7203 - val_loss: 0.7901 - val_accuracy: 0.7782
# Epoch 26/40
# 9/9 [==============================] - 0s 38ms/step - loss: 0.7252 - accuracy: 0.7037 - val_loss: 0.9386 - val_accuracy: 0.8198
# Epoch 27/40
# 9/9 [==============================] - 0s 37ms/step - loss: 0.7162 - accuracy: 0.7204 - val_loss: 0.7861 - val_accuracy: 0.7730
# Epoch 28/40
# 9/9 [==============================] - 0s 39ms/step - loss: 0.6769 - accuracy: 0.7443 - val_loss: 0.6684 - val_accuracy: 0.8440
# Epoch 29/40
# 9/9 [==============================] - 0s 39ms/step - loss: 0.6706 - accuracy: 0.7268 - val_loss: 0.8208 - val_accuracy: 0.8094
# Epoch 30/40
# 9/9 [==============================] - 0s 38ms/step - loss: 0.6508 - accuracy: 0.7384 - val_loss: 0.7006 - val_accuracy: 0.8076
# Epoch 31/40
# 9/9 [==============================] - 0s 39ms/step - loss: 0.6649 - accuracy: 0.7346 - val_loss: 0.6620 - val_accuracy: 0.9099
# Epoch 32/40
# 9/9 [==============================] - 0s 38ms/step - loss: 0.6629 - accuracy: 0.7539 - val_loss: 0.6763 - val_accuracy: 0.8475
# Epoch 33/40
# 9/9 [==============================] - 0s 38ms/step - loss: 0.6623 - accuracy: 0.7328 - val_loss: 0.8209 - val_accuracy: 0.7712
# Epoch 34/40
# 9/9 [==============================] - 0s 38ms/step - loss: 0.6040 - accuracy: 0.7629 - val_loss: 0.6153 - val_accuracy: 0.8821
# Epoch 35/40
# 9/9 [==============================] - 0s 39ms/step - loss: 0.6114 - accuracy: 0.7484 - val_loss: 0.5167 - val_accuracy: 0.8960
# Epoch 36/40
# 9/9 [==============================] - 0s 38ms/step - loss: 0.6311 - accuracy: 0.7605 - val_loss: 0.8136 - val_accuracy: 0.7868
# Epoch 37/40
# 9/9 [==============================] - 0s 39ms/step - loss: 0.6066 - accuracy: 0.7697 - val_loss: 0.5921 - val_accuracy: 0.8960
# Epoch 38/40
# 9/9 [==============================] - 0s 38ms/step - loss: 0.6181 - accuracy: 0.7660 - val_loss: 0.4294 - val_accuracy: 0.9220
# Epoch 39/40
# 9/9 [==============================] - 0s 38ms/step - loss: 0.6112 - accuracy: 0.7706 - val_loss: 0.6164 - val_accuracy: 0.8440
# Epoch 40/40
# 9/9 [==============================] - 0s 38ms/step - loss: 0.5582 - accuracy: 0.7790 - val_loss: 0.4506 - val_accuracy: 0.8735

# %%
# Plots

dist_hist_ln1 = history_model_ln1.history
iepoch = np.arange(1,41)

plot_acc(dist_hist_ln1, iepoch)

# %%
# With Dropout and with Batch Normalization

lr = 0.001
kernelsize = 5
model_ln2 = LNmodel(in_shape, [8,16], [16,8], kernelsize, num_classes, lr,
                    stride=1, pool_size=2, leakyrelu_slope=0.1, dropc=0.25, 
                    dropd=0.5, bnorm=True)
model_ln2.summary()
# Out:
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 150, 150, 1)]     0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 150, 150, 8)       208
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 150, 150, 8)       0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 150, 150, 8)       0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 150, 150, 8)       32
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 75, 75, 8)         0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 75, 75, 16)        3216
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 75, 75, 16)        0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 75, 75, 16)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 75, 75, 16)        64
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 37, 37, 16)        0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 21904)             0
# _________________________________________________________________
# dense_18 (Dense)             (None, 16)                350480
# _________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)   (None, 16)                0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 16)                0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16)                64
# _________________________________________________________________
# dense_19 (Dense)             (None, 8)                 136
# _________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)   (None, 8)                 0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8)                 32
# _________________________________________________________________
# dense_20 (Dense)             (None, 4)                 36
# =================================================================
# Total params: 354,268
# Trainable params: 354,172
# Non-trainable params: 96
# _________________________________________________________________

# %%
history_model_ln2 = model_ln2.fit(X_train, y_train_e, 
                                  validation_split=0.2,
                                  verbose=1, batch_size=256, 
                                  shuffle=True, epochs=40)
# Out:
# Epoch 1/40
# 9/9 [==============================] - 2s 82ms/step - loss: 1.5348 - accuracy: 0.3421 - val_loss: 1.2516 - val_accuracy: 0.7972
# Epoch 2/40
# 9/9 [==============================] - 0s 52ms/step - loss: 1.3584 - accuracy: 0.4332 - val_loss: 0.9806 - val_accuracy: 0.9948
# Epoch 3/40
# 9/9 [==============================] - 0s 53ms/step - loss: 1.2868 - accuracy: 0.4737 - val_loss: 0.8202 - val_accuracy: 1.0000
# Epoch 4/40
# 9/9 [==============================] - 0s 51ms/step - loss: 1.2023 - accuracy: 0.4933 - val_loss: 0.8113 - val_accuracy: 1.0000
# Epoch 5/40
# 9/9 [==============================] - 0s 53ms/step - loss: 1.1839 - accuracy: 0.5177 - val_loss: 0.7967 - val_accuracy: 1.0000
# Epoch 6/40
# 9/9 [==============================] - 0s 53ms/step - loss: 1.0829 - accuracy: 0.5714 - val_loss: 0.8510 - val_accuracy: 1.0000
# Epoch 7/40
# 9/9 [==============================] - 0s 52ms/step - loss: 1.0903 - accuracy: 0.5506 - val_loss: 0.8743 - val_accuracy: 1.0000
# Epoch 8/40
# 9/9 [==============================] - 0s 51ms/step - loss: 1.0442 - accuracy: 0.5766 - val_loss: 0.9117 - val_accuracy: 0.9809
# Epoch 9/40
# 9/9 [==============================] - 0s 51ms/step - loss: 0.9985 - accuracy: 0.6055 - val_loss: 0.9009 - val_accuracy: 0.9792
# Epoch 10/40
# 9/9 [==============================] - 0s 52ms/step - loss: 0.9590 - accuracy: 0.6212 - val_loss: 0.9514 - val_accuracy: 0.4471
# Epoch 11/40
# 9/9 [==============================] - 0s 51ms/step - loss: 0.9200 - accuracy: 0.6404 - val_loss: 1.0275 - val_accuracy: 0.0468
# Epoch 12/40
# 9/9 [==============================] - 0s 53ms/step - loss: 0.9006 - accuracy: 0.6332 - val_loss: 0.9410 - val_accuracy: 0.7158
# Epoch 13/40
# 9/9 [==============================] - 0s 52ms/step - loss: 0.8775 - accuracy: 0.6280 - val_loss: 0.9911 - val_accuracy: 0.4038
# Epoch 14/40
# 9/9 [==============================] - 0s 52ms/step - loss: 0.8365 - accuracy: 0.6547 - val_loss: 0.9361 - val_accuracy: 0.6932
# Epoch 15/40
# 9/9 [==============================] - 0s 52ms/step - loss: 0.8257 - accuracy: 0.6624 - val_loss: 0.9791 - val_accuracy: 0.4263
# Epoch 16/40
# 9/9 [==============================] - 0s 52ms/step - loss: 0.7635 - accuracy: 0.7100 - val_loss: 1.0854 - val_accuracy: 0.0815
# Epoch 17/40
# 9/9 [==============================] - 0s 52ms/step - loss: 0.7453 - accuracy: 0.7169 - val_loss: 1.1418 - val_accuracy: 0.0173
# Epoch 18/40
# 9/9 [==============================] - 0s 51ms/step - loss: 0.7181 - accuracy: 0.7167 - val_loss: 1.2487 - val_accuracy: 0.0017
# Epoch 19/40
# 9/9 [==============================] - 0s 52ms/step - loss: 0.7313 - accuracy: 0.7125 - val_loss: 1.3346 - val_accuracy: 0.0000e+00
# Epoch 20/40
# 9/9 [==============================] - 0s 53ms/step - loss: 0.6894 - accuracy: 0.7280 - val_loss: 1.3304 - val_accuracy: 0.0000e+00
# Epoch 21/40
# 9/9 [==============================] - 0s 52ms/step - loss: 0.6914 - accuracy: 0.7293 - val_loss: 1.2780 - val_accuracy: 0.0017
# Epoch 22/40
# 9/9 [==============================] - 0s 51ms/step - loss: 0.6561 - accuracy: 0.7379 - val_loss: 1.2576 - val_accuracy: 0.0052
# Epoch 23/40
# 9/9 [==============================] - 0s 53ms/step - loss: 0.6463 - accuracy: 0.7520 - val_loss: 1.4790 - val_accuracy: 0.0000e+00
# Epoch 24/40
# 9/9 [==============================] - 0s 51ms/step - loss: 0.6190 - accuracy: 0.7792 - val_loss: 1.4643 - val_accuracy: 0.0000e+00
# Epoch 25/40
# 9/9 [==============================] - 0s 52ms/step - loss: 0.6201 - accuracy: 0.7665 - val_loss: 1.5272 - val_accuracy: 0.0017
# Epoch 26/40
# 9/9 [==============================] - 0s 52ms/step - loss: 0.6009 - accuracy: 0.7893 - val_loss: 1.3968 - val_accuracy: 0.0069
# Epoch 27/40
# 9/9 [==============================] - 0s 52ms/step - loss: 0.6030 - accuracy: 0.7729 - val_loss: 1.3452 - val_accuracy: 0.0104
# Epoch 28/40
# 9/9 [==============================] - 0s 52ms/step - loss: 0.5805 - accuracy: 0.7940 - val_loss: 1.2612 - val_accuracy: 0.0433
# Epoch 29/40
# 9/9 [==============================] - 0s 52ms/step - loss: 0.5591 - accuracy: 0.7855 - val_loss: 1.3932 - val_accuracy: 0.0156
# Epoch 30/40
# 9/9 [==============================] - 0s 53ms/step - loss: 0.5592 - accuracy: 0.8035 - val_loss: 1.3050 - val_accuracy: 0.0797
# Epoch 31/40
# 9/9 [==============================] - 0s 51ms/step - loss: 0.5413 - accuracy: 0.7999 - val_loss: 1.1717 - val_accuracy: 0.1733
# Epoch 32/40
# 9/9 [==============================] - 0s 51ms/step - loss: 0.5058 - accuracy: 0.8241 - val_loss: 1.0610 - val_accuracy: 0.3917
# Epoch 33/40
# 9/9 [==============================] - 0s 52ms/step - loss: 0.5313 - accuracy: 0.8153 - val_loss: 1.2670 - val_accuracy: 0.1300
# Epoch 34/40
# 9/9 [==============================] - 0s 52ms/step - loss: 0.4972 - accuracy: 0.8252 - val_loss: 1.2049 - val_accuracy: 0.2444
# Epoch 35/40
# 9/9 [==============================] - 0s 52ms/step - loss: 0.5007 - accuracy: 0.8172 - val_loss: 1.2341 - val_accuracy: 0.2028
# Epoch 36/40
# 9/9 [==============================] - 0s 52ms/step - loss: 0.4946 - accuracy: 0.8230 - val_loss: 1.0460 - val_accuracy: 0.4922
# Epoch 37/40
# 9/9 [==============================] - 0s 52ms/step - loss: 0.4863 - accuracy: 0.8289 - val_loss: 0.9717 - val_accuracy: 0.5494
# Epoch 38/40
# 9/9 [==============================] - 0s 52ms/step - loss: 0.4827 - accuracy: 0.8281 - val_loss: 0.9722 - val_accuracy: 0.6274
# Epoch 39/40
# 9/9 [==============================] - 0s 52ms/step - loss: 0.4680 - accuracy: 0.8364 - val_loss: 0.8783 - val_accuracy: 0.7920
# Epoch 40/40
# 9/9 [==============================] - 0s 51ms/step - loss: 0.4872 - accuracy: 0.8291 - val_loss: 0.8654 - val_accuracy: 0.7470

# %%
# Plots

dict_hist_ln2 = history_model_ln2.history
iepoch = np.arange(1,41)
plot_acc(dict_hist_ln2, iepoch)

# %% [markdown]
# Batch normalization does not perform well. Below, only Dropout is used.

# %% [markdown]
# A validation split of 0.1 is used below to provide more training data.

# %%
# Conv2D 8 filters 5X5, MaxPool2D 2X2, Conv2D 16 filters 5X5, MaxPool2D, 2X2
# 2 Dense layers 512, 256 units
# Dropout 0.25 after conv layers, 0.5 after dense layers
# validation split = 0.1

lr = 0.001
kernelsize = 5
model_ln3 = LNmodel(in_shape, [8,16], [512,256], kernelsize, num_classes, lr,
                    stride=1, pool_size=2, leakyrelu_slope=0.1, dropc=0.25,
                    dropd=0.5, bnorm=False)
model_ln3.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 150, 150, 1)]     0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 150, 150, 8)       208
# _________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)   (None, 150, 150, 8)       0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 150, 150, 8)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 75, 75, 8)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 75, 75, 16)        3216
# _________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)   (None, 75, 75, 16)        0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 75, 75, 16)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 37, 37, 16)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 21904)             0
# _________________________________________________________________
# dense_15 (Dense)             (None, 512)               11215360
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 512)               0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               131328
# _________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 4)                 1028
# =================================================================
# Total params: 11,351,140
# Trainable params: 11,351,140
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping

# %%
# Early stopping (commented out as it did not improve performance)
Estopp = EarlyStopping(monitor='val_loss', patience=5)

history_model_ln3 = model_ln3.fit(X_train, y_train_e, 
                                  validation_split=0.1,
                                  verbose=1, batch_size=512, 
                               #   callbacks=[Estopp],
                                  shuffle=True, epochs=40)
# Out:
# Epoch 1/40
# 6/6 [==============================] - 1s 91ms/step - loss: 2.5152 - accuracy: 0.3171 - val_loss: 1.3387 - val_accuracy: 0.1765
# Epoch 2/40
# 6/6 [==============================] - 0s 59ms/step - loss: 1.2941 - accuracy: 0.3814 - val_loss: 1.1457 - val_accuracy: 0.8478
# Epoch 3/40
# 6/6 [==============================] - 0s 59ms/step - loss: 1.1141 - accuracy: 0.4996 - val_loss: 0.9243 - val_accuracy: 0.7924
# Epoch 4/40
# 6/6 [==============================] - 0s 59ms/step - loss: 0.9639 - accuracy: 0.5697 - val_loss: 0.6222 - val_accuracy: 0.8166
# Epoch 5/40
# 6/6 [==============================] - 0s 58ms/step - loss: 0.8473 - accuracy: 0.6254 - val_loss: 0.3291 - val_accuracy: 0.9343
# Epoch 6/40
# 6/6 [==============================] - 0s 59ms/step - loss: 0.7679 - accuracy: 0.6751 - val_loss: 0.4912 - val_accuracy: 0.8997
# Epoch 7/40
# 6/6 [==============================] - 0s 56ms/step - loss: 0.6780 - accuracy: 0.7095 - val_loss: 0.3017 - val_accuracy: 0.9446
# Epoch 8/40
# 6/6 [==============================] - 0s 61ms/step - loss: 0.6491 - accuracy: 0.7050 - val_loss: 0.3635 - val_accuracy: 0.9135
# Epoch 9/40
# 6/6 [==============================] - 0s 58ms/step - loss: 0.5952 - accuracy: 0.7469 - val_loss: 0.3453 - val_accuracy: 0.8997
# Epoch 10/40
# 6/6 [==============================] - 0s 59ms/step - loss: 0.5270 - accuracy: 0.7710 - val_loss: 0.2866 - val_accuracy: 0.8997
# Epoch 11/40
# 6/6 [==============================] - 0s 60ms/step - loss: 0.5282 - accuracy: 0.7863 - val_loss: 0.4376 - val_accuracy: 0.8408
# Epoch 12/40
# 6/6 [==============================] - 0s 57ms/step - loss: 0.5170 - accuracy: 0.7861 - val_loss: 0.2245 - val_accuracy: 0.9239
# Epoch 13/40
# 6/6 [==============================] - 0s 58ms/step - loss: 0.0484 - accuracy: 0.9845 - val_loss: 0.1261 - val_accuracy: 0.9550
# Epoch 37/40
# 6/6 [==============================] - 0s 58ms/step - loss: 0.0388 - accuracy: 0.9907 - val_loss: 0.0872 - val_accuracy: 0.9619
# Epoch 38/40
# 6/6 [==============================] - 0s 59ms/step - loss: 0.0403 - accuracy: 0.9860 - val_loss: 0.1098 - val_accuracy: 0.9550
# Epoch 39/40
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0518 - accuracy: 0.9825 - val_loss: 0.0441 - val_accuracy: 0.9862
# Epoch 40/40
# 6/6 [==============================] - 0s 56ms/step - loss: 0.0365 - accuracy: 0.9904 - val_loss: 0.0618 - val_accuracy: 0.9827

# %%
# Plots

dict_hist_ln3 = history_model_ln3.history
iepoch = np.arange(1,41)
plot_acc(dict_hist_ln3, iepoch)

# %% [markdown]
# Other models and hyperparameters were tried, with or without an additional dropout layer between the convolutional and dense layers, with the convolutional layers having filters of 8, 16, 32, 64 or up to 128, and 2 or 3 dense layers having units of 1024, 512, 256, 128, or 32. Different leaky relu slopes (0.2 or 0) were tried but 0.1 performed better. Kernel size of 3 or 5 was tried. The validation split was set to 0.1 or 0.2.
#
# Findings:
# * Filters of 8, 16 are sufficient in Conv layer
# * Number of units in dense layer can be increased (for example, up to 1024, 512, 256)
# * Using 8 and 16 units in dense layers did not perform well
# * Leaky relu slope of 0.1 performs well
# * Dropout of 0.25 for conv layers and 0.5 for dense layers performs well
# * Validation split of 0.1 gives more training data and can improve accuracy

# %% [markdown]
# ## ***Making predictions on the test images with the models providing good validation accuracy:*** ##

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
# Test prediction with model cnn3 
# CNN with 8 and 16 filters in Conv2D layers, and 16 units in fully connected dense layer
# kernel size of 3
# No Dropout layers

y_test_pred_cnn3 = model_cnn3.predict(X_test)
y_test_pred_classes_cnn3 = np.argmax(y_test_pred_cnn3, axis=1)

# %%
accuracy_score(y_test, y_test_pred_classes_cnn3)
# Out:
# 0.7412935323383084

# %%
cf_matrix = confusion_matrix(y_test, y_test_pred_classes_cnn3)

# Confusion matrix normalized per category true value
cf_matrix_n1 = cf_matrix/np.sum(cf_matrix, axis=1)
plt.figure(figsize=(8,6))
ax = sns.heatmap(cf_matrix_n1, xticklabels=CATEGORIES, yticklabels=CATEGORIES, annot=True)
ax.set_xticklabels(Cat_names)
ax.set_yticklabels(Cat_names)
# Out:
# [Text(0, 0.5, 'Glioma'),
#  Text(0, 1.5, 'Meningioma'),
#  Text(0, 2.5, 'None'),
#  Text(0, 3.5, 'Pituitary')]

# %%
# Test prediction with model_cnndo1, 
# Conv2D 8,16,32,16,8 filters, dense layer with 32 units
# with Dropout layers

y_test_predcdo1 = model_cnndo1.predict(X_test)
y_test_pred_classescdo1 = np.argmax(y_test_predcdo1, axis=1)
y_test_pred_probcdo1 = np.max(y_test_predcdo1, axis=1)

# %%
accuracy_score(y_test, y_test_pred_classescdo1)
# Out:
# 0.6766169154228856

# %%
cf_matrix = confusion_matrix(y_test, y_test_pred_classescdo1)

# Confusion matrix normalized per category true value
cf_matrix = cf_matrix/np.sum(cf_matrix, axis=1)
plt.figure(figsize=(8,6))
ax = sns.heatmap(cf_matrix, xticklabels=CATEGORIES, yticklabels=CATEGORIES, annot=True)
ax.set_xticklabels(Cat_names)
ax.set_yticklabels(Cat_names)
# Out:
# [Text(0, 0.5, 'Glioma'),
#  Text(0, 1.5, 'Meningioma'),
#  Text(0, 2.5, 'None'),
#  Text(0, 3.5, 'Pituitary')]

# %%
# Test prediction with model_ln3, 
# Conv2D 8 filters 5X5, MaxPool2D 2X2, Conv2D 16 filters 5X5, MaxPool2D, 2X2
# 2 Dense layers 512, 256 units
# with Dropout layers

y_test_pred_ln3 = model_ln3.predict(X_test)
y_test_pred_classes_ln3 = np.argmax(y_test_pred_ln3, axis=1)
y_test_pred_prob_ln3 = np.max(y_test_pred_ln3, axis=1)

# %%
accuracy_score(y_test, y_test_pred_classes_ln3)
# Out:
# 0.7711442786069652

# %%
cf_matrix = confusion_matrix(y_test, y_test_pred_classes_ln3)

# Confusion matrix normalized per category true value
cf_matrix_n1 = cf_matrix/np.sum(cf_matrix, axis=1)
plt.figure(figsize=(8,6))
ax = sns.heatmap(cf_matrix_n1, xticklabels=CATEGORIES, yticklabels=CATEGORIES, annot=True)
ax.set_xticklabels(Cat_names)
ax.set_yticklabels(Cat_names)
# Out:
# [Text(0, 0.5, 'Glioma'),
#  Text(0, 1.5, 'Meningioma'),
#  Text(0, 2.5, 'None'),
#  Text(0, 3.5, 'Pituitary')]

# %% [markdown]
# ### Conclusions: ###
# * The models developed here provide a maximum accuracy of about 0.77 on the test set.
# * The meningioma tumors and no tumors can be predicted well, but pituitary and especially glioma tumors are not predicted well.
# * The prediction of pituitary tumors could be improved with LeNet-5-type architecture, but the glioma tumors are not predicted well.

# %% [markdown]
# ## Grid Search Hyperparameters ##

# %% [markdown]
# Try Grid Search using the CNN model.
#
# Using the more complicated architectures with dropout layers or LeNet-5 did not provide a large improvement. So the CNN model is tried here.

# %%
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier

# %%
# Model definition
def create_model(learn_rate=0.001):
  kernel_size = 3
  leakyrelu_slope = 0.1
  model = Sequential()
  model.add(Conv2D(filters=8, kernel_size=kernel_size, padding='same', input_shape=in_shape))
  model.add(LeakyReLU(leakyrelu_slope))
  model.add(Conv2D(filters=16, kernel_size=kernel_size, padding='same'))
  model.add(LeakyReLU(leakyrelu_slope))
  model.add(MaxPool2D(pool_size=2))
  model.add(Flatten())
  model.add(Dense(16))
  model.add(LeakyReLU(leakyrelu_slope))
  model.add(Dense(num_classes, activation='softmax'))
  adam = optimizers.Adam(lr=learn_rate)
  model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
  return model

# Grid search for learning rate and batch size
smodel = KerasClassifier(build_fn=create_model, verbose=0, epochs=20)
param_grid = {'learn_rate': [0.001, 0.005, 0.01], 'batch_size': [64, 128, 256, 512]}
grid = GridSearchCV(estimator=smodel, param_grid=param_grid, n_jobs=1, cv=5, 
                    return_train_score=True)

grid_result = grid.fit(X_train, y_train_e)

grid_result.cv_results_

# Notes: did not work for epochs
# predict_classes method is only available for the Sequential class 
# but not for the Model class
# Out:
# {'mean_fit_time': array([6.73257427, 7.02899361, 6.72137218, 6.33452239, 6.3184577 ,
#         6.34257779, 6.26131725, 6.1129858 , 6.10573015, 6.1339931 ,
#         6.00607953, 6.00552015]),
#  'mean_score_time': array([0.20546956, 0.20721302, 0.3397665 , 0.21378832, 0.22186027,
#         0.21873727, 0.21203566, 0.21119227, 0.20991254, 0.20791683,
#         0.20605931, 0.20842381]),
#  'mean_test_score': array([0.71678342, 0.67791859, 0.66436729, 0.69974244, 0.63658048,
#         0.59879404, 0.58554844, 0.6216698 , 0.66434565, 0.61478793,
#         0.63112904, 0.55270014]),
#  'mean_train_score': array([1.        , 1.        , 1.        , 0.99592191, 0.97492408,
#         0.91391958, 0.93856728, 0.9645987 , 0.87557472, 0.95748063,
#         0.97430793, 0.8988094 ]),
#  'param_batch_size': masked_array(data=[64, 64, 64, 128, 128, 128, 256, 256, 256, 512, 512,
#                     512],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_learn_rate': masked_array(data=[0.001, 0.005, 0.01, 0.001, 0.005, 0.01, 0.001, 0.005,
#                     0.01, 0.001, 0.005, 0.01],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'batch_size': 64, 'learn_rate': 0.001},
#   {'batch_size': 64, 'learn_rate': 0.005},
#   {'batch_size': 64, 'learn_rate': 0.01},
#   {'batch_size': 128, 'learn_rate': 0.001},
#   {'batch_size': 128, 'learn_rate': 0.005},
#   {'batch_size': 128, 'learn_rate': 0.01},
#   {'batch_size': 256, 'learn_rate': 0.001},
#   {'batch_size': 256, 'learn_rate': 0.005},
#   {'batch_size': 256, 'learn_rate': 0.01},
#   {'batch_size': 512, 'learn_rate': 0.001},
#   {'batch_size': 512, 'learn_rate': 0.005},
#   {'batch_size': 512, 'learn_rate': 0.01}],
#  'rank_test_score': array([ 1,  3,  4,  2,  6, 10, 11,  8,  5,  9,  7, 12], dtype=int32),
#  'split0_test_score': array([0.66377819, 0.59445405, 0.62218368, 0.74176776, 0.64818025,
#         0.4731369 , 0.62045062, 0.59098786, 0.68457538, 0.41074523,
#         0.34835356, 0.2235702 ]),
#  'split0_train_score': array([1.        , 1.        , 1.        , 1.        , 1.        ,
#         0.92317706, 0.98784721, 1.        , 0.99869794, 0.96440971,
#         0.89887154, 0.77821183]),
#  'split1_test_score': array([0.78819442, 0.7795139 , 0.7829861 , 0.75694442, 0.58506942,
#         0.73958331, 0.71006942, 0.7361111 , 0.71354169, 0.76909721,
#         0.77083331, 0.74131942]),
#  'split1_train_score': array([1.        , 1.        , 1.        , 0.98568332, 0.87462038,
#         1.        , 0.95835143, 1.        , 0.95748371, 0.97049892,
#         1.        , 0.95271152]),
#  'split2_test_score': array([0.609375  , 0.52083331, 0.5017361 , 0.515625  , 0.4548611 ,
#         0.51215279, 0.27083334, 0.30555555, 0.79340279, 0.4079861 ,
#         0.53645831, 0.58159721]),
#  'split2_train_score': array([1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 0.89414316, 0.94013017, 0.70889372, 0.98872018,
#         0.99739695, 0.99696314]),
#  'split3_test_score': array([0.59027779, 0.6076389 , 0.578125  , 0.57118058, 0.58506942,
#         0.39409721, 0.60069442, 0.54340279, 0.52604169, 0.578125  ,
#         0.58159721, 0.41840279]),
#  'split3_train_score': array([1.        , 1.        , 1.        , 1.        , 1.        ,
#         0.65119308, 0.98568332, 0.97657269, 0.91236442, 0.97006506,
#         0.99566162, 0.85726678]),
#  'split4_test_score': array([0.93229169, 0.88715279, 0.83680558, 0.91319442, 0.90972221,
#         0.875     , 0.72569442, 0.93229169, 0.60416669, 0.9079861 ,
#         0.91840279, 0.7986111 ]),
#  'split4_train_score': array([1.        , 1.        , 1.        , 0.99392623, 1.        ,
#         0.99522775, 0.86681128, 0.90629065, 0.80043381, 0.8937093 ,
#         0.97960955, 0.9088937 ]),
#  'std_fit_time': array([0.17474487, 0.49333082, 0.10447327, 0.05833282, 0.08247565,
#         0.10102541, 0.31358603, 0.04625438, 0.06363096, 0.01329889,
#         0.02089066, 0.01902837]),
#  'std_score_time': array([0.00851935, 0.00905642, 0.26741335, 0.00272195, 0.00686168,
#         0.00640395, 0.00141692, 0.00398536, 0.00672517, 0.00472338,
#         0.00353148, 0.00364282]),
#  'std_test_score': array([0.12797901, 0.13467138, 0.12607258, 0.14214593, 0.1503793 ,
#         0.17961546, 0.16470551, 0.20812405, 0.09190727, 0.19774788,
#         0.1966832 , 0.21130394]),
#  'std_train_score': array([0.        , 0.        , 0.        , 0.0056339 , 0.05015185,
#         0.13456717, 0.04931992, 0.03646483, 0.10644304, 0.03291974,
#         0.03838729, 0.07604058])}

# %%
print("Best score: {}, parameters: {}".format(grid_result.best_score_, 
                                          grid_result.best_params_))
mean = grid_result.cv_results_['mean_test_score']
std = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
print(mean, std, params)
# Out:
# Best score: 0.7167834162712097, parameters: {'batch_size': 64, 'learn_rate': 0.001}
# [0.71678342 0.67791859 0.66436729 0.69974244 0.63658048 0.59879404
#  0.58554844 0.6216698  0.66434565 0.61478793 0.63112904 0.55270014] [0.12797901 0.13467138 0.12607258 0.14214593 0.1503793  0.17961546
#  0.16470551 0.20812405 0.09190727 0.19774788 0.1966832  0.21130394] [{'batch_size': 64, 'learn_rate': 0.001}, {'batch_size': 64, 'learn_rate': 0.005}, {'batch_size': 64, 'learn_rate': 0.01}, {'batch_size': 128, 'learn_rate': 0.001}, {'batch_size': 128, 'learn_rate': 0.005}, {'batch_size': 128, 'learn_rate': 0.01}, {'batch_size': 256, 'learn_rate': 0.001}, {'batch_size': 256, 'learn_rate': 0.005}, {'batch_size': 256, 'learn_rate': 0.01}, {'batch_size': 512, 'learn_rate': 0.001}, {'batch_size': 512, 'learn_rate': 0.005}, {'batch_size': 512, 'learn_rate': 0.01}]

# %% [markdown]
# ### Conclusions ###
# Grid Search with 5-fold cross-validation gave various solutions, such as batch size 64, lr 0.001; batch size 256, lr 0.005; and batch size 512, lr 0.005. Learning rate of 0.001 or 0.005 works better, but batch size does not have much effect.

# %% [markdown]
# ## Keras Tuner ##

# %% [markdown]
# Try keras tuner for tuning the models.

# %%
# !pip install -U keras-tuner
# Out:
# Collecting keras-tuner
#   Downloading https://files.pythonhosted.org/packages/20/ec/1ef246787174b1e2bb591c95f29d3c1310070cad877824f907faba3dade9/keras-tuner-1.0.2.tar.gz (62kB)
#      |████████████████████████████████| 71kB 6.9MB/s
# Requirement already satisfied, skipping upgrade: packaging in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (20.8)
# Requirement already satisfied, skipping upgrade: future in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (0.16.0)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (1.19.5)
# Requirement already satisfied, skipping upgrade: tabulate in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (0.8.7)
# Collecting terminaltables
#   Downloading https://files.pythonhosted.org/packages/9b/c4/4a21174f32f8a7e1104798c445dacdc1d4df86f2f26722767034e4de4bff/terminaltables-3.1.0.tar.gz
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: tqdm in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (4.41.1)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (2.23.0)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (1.4.1)
# Requirement already satisfied, skipping upgrade: scikit-learn in /usr/local/lib/python3.6/dist-packages (from keras-tuner) (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->keras-tuner) (2.4.7)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->keras-tuner) (2020.12.5)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->keras-tuner) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->keras-tuner) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->keras-tuner) (2.10)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->keras-tuner) (1.0.0)
# Building wheels for collected packages: keras-tuner, terminaltables
#   Building wheel for keras-tuner (setup.py) ... done
#   Created wheel for keras-tuner: filename=keras_tuner-1.0.2-cp36-none-any.whl size=78939 sha256=ad3056c099c841efbaf3499a377516be3c588dcf415c2c9409b715211615ad06
#   Stored in directory: /root/.cache/pip/wheels/bb/a1/8a/7c3de0efb3707a1701b36ebbfdbc4e67aedf6d4943a1f463d6
#   Building wheel for terminaltables (setup.py) ... done
#   Created wheel for terminaltables: filename=terminaltables-3.1.0-cp36-none-any.whl size=15358 sha256=aecf3c1cc3976a6a106ecd9ca5fb4a0349273e05d4c344adb9290cc4970d5707
#   Stored in directory: /root/.cache/pip/wheels/30/6b/50/6c75775b681fb36cdfac7f19799888ef9d8813aff9e379663e
# Successfully built keras-tuner terminaltables
# Installing collected packages: terminaltables, colorama, keras-tuner
# Successfully installed colorama-0.4.4 keras-tuner-1.0.2 terminaltables-3.1.0

# %%
from kerastuner.tuners import RandomSearch, BayesianOptimization
from kerastuner import HyperModel

# %%
# Define model: CNN model with dropout layer

class CNNhypermodel(HyperModel):
  def __init__(self, in_shape, num_classes):
    self.in_shape = in_shape
    self.num_classes = num_classes

  def build(self, hp):
    inputs = Input(shape=self.in_shape)
    for idx, i in enumerate(range(hp.Int('num_layers', 2, 8, step=2))):
      x = inputs if idx==0 else x
      x = Conv2D(filters=hp.Int('filter'+str(i), min_value=8, max_value=256, step=16),
                 kernel_size=hp.Int('kernel_size'+str(i), min_value=3, max_value=6, step=1),
                 padding='same')(x)
      x = LeakyReLU(0.1)(x)
    x = MaxPool2D(pool_size=hp.Int('pool_size', min_value=2, max_value=4, step=1))(x)
    x = Dropout(hp.Float('dropout_1', min_value=0.0, max_value=0.6, step=0.2))(x)
    x = Flatten()(x)
    x = Dense(hp.Int('dense_units', min_value=16, max_value=256, step=16))(x)
    x = LeakyReLU(0.1)(x)
    x = Dropout(hp.Float('dropout_2', min_value=0.0, max_value=0.6, step=0.2))(x)
    x = Dense(self.num_classes, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=x)

    model.compile(loss='categorical_crossentropy', 
                  optimizer=optimizers.Adam(lr=0.001),
                  metrics=['accuracy'])
    return model
    
chmodel = CNNhypermodel(in_shape=in_shape, num_classes=num_classes)

# Using RandomSearch
tuner1 = RandomSearch(chmodel,
                      objective='val_accuracy',
                      max_trials=5,
                      directory='.',
                      project_name='capstone'
                     )

tuner1.search(X_train, y_train_e, epochs=20, validation_split=0.2, shuffle=True)

tuner1.results_summary()
# Out:
# Trial 5 Complete [00h 14m 56s]
# val_accuracy: 0.9289427995681763
#
# Best val_accuracy So Far: 0.941074550151825
# Total elapsed time: 00h 45m 51s
# INFO:tensorflow:Oracle triggered exit
# Results summary
# Results in ./capstone
# Showing 10 best trials
# Objective(name='val_accuracy', direction='max')
# Trial summary
# Hyperparameters:
# num_layers: 6
# filter0: 200
# kernel_size0: 6
# filter1: 248
# kernel_size1: 5
# pool_size: 4
# dropout_1: 0.4
# dense_units: 144
# dropout_2: 0.0
# filter2: 184
# kernel_size2: 6
# filter3: 136
# kernel_size3: 5
# filter4: 40
# kernel_size4: 3
# filter5: 184
# kernel_size5: 4
# Score: 0.941074550151825
# Trial summary
# Hyperparameters:
# num_layers: 8
# filter0: 184
# kernel_size0: 5
# filter1: 56
# kernel_size1: 5
# pool_size: 3
# dropout_1: 0.0
# dense_units: 144
# dropout_2: 0.4
# filter2: 72
# kernel_size2: 6
# filter3: 24
# kernel_size3: 4
# filter4: 72
# kernel_size4: 4
# filter5: 24
# kernel_size5: 5
# filter6: 8
# kernel_size6: 3
# filter7: 8
# kernel_size7: 3
# Score: 0.9341421127319336
# Trial summary
# Hyperparameters:
# num_layers: 6
# filter0: 104
# kernel_size0: 4
# filter1: 88
# kernel_size1: 6
# pool_size: 3
# dropout_1: 0.6000000000000001
# dense_units: 80
# dropout_2: 0.6000000000000001
# filter2: 8
# kernel_size2: 3
# filter3: 8
# kernel_size3: 3
# filter4: 8
# kernel_size4: 3
# filter5: 8
# kernel_size5: 3
# Score: 0.9324089884757996
# Trial summary
# Hyperparameters:
# num_layers: 6
# filter0: 248
# kernel_size0: 4
# filter1: 248
# kernel_size1: 4
# pool_size: 3
# dropout_1: 0.6000000000000001
# dense_units: 32
# dropout_2: 0.0
# filter2: 184
# kernel_size2: 5
# filter3: 216
# kernel_size3: 5
# filter4: 40
# kernel_size4: 5
# filter5: 24
# kernel_size5: 4
# filter6: 152
# kernel_size6: 3
# filter7: 40
# kernel_size7: 5
# Score: 0.9289427995681763
# Trial summary
# Hyperparameters:
# num_layers: 6
# filter0: 200
# kernel_size0: 3
# filter1: 152
# kernel_size1: 6
# pool_size: 3
# dropout_1: 0.0
# dense_units: 48
# dropout_2: 0.2
# filter2: 168
# kernel_size2: 4
# filter3: 24
# kernel_size3: 5
# filter4: 248
# kernel_size4: 4
# filter5: 184
# kernel_size5: 4
# filter6: 72
# kernel_size6: 4
# filter7: 88
# kernel_size7: 4
# Score: 0.9289427995681763

# %%
model1 = tuner1.get_best_models(num_models=1)[0]

history_mod1 = model1.fit(X_train, y_train_e, validation_split=0.2, shuffle=True, epochs=20, verbose=1, batch_size=32)
# Out:
# Epoch 1/20
# 72/72 [==============================] - 42s 571ms/step - loss: 0.1660 - accuracy: 0.9338 - val_loss: 0.3228 - val_accuracy: 0.9376
# Epoch 2/20
# 72/72 [==============================] - 41s 568ms/step - loss: 0.1615 - accuracy: 0.9418 - val_loss: 0.4730 - val_accuracy: 0.9099
# Epoch 3/20
# %%
y_test_pred_hmod1 = model1.predict(X_test)
y_test_pred_hmod1_cl = np.argmax(y_test_pred_hmod1, axis=1)

# %%
accuracy_score(y_test, y_test_pred_hmod1_cl)
# Out:
# 0.7014925373134329

# %%
cm_hmod1 = confusion_matrix(y_test, y_test_pred_hmod1_cl)
cm_hmod1 = cm_hmod1/np.sum(cm_hmod1, axis=1)
plt.figure(figsize=(5,4))
ax = sns.heatmap(cm_hmod1, annot=True)
ax.set_xticklabels(Cat_names, rotation=30)
ax.set_yticklabels(Cat_names, rotation=30)
# Out:
# [Text(0, 0.5, 'Glioma'),
#  Text(0, 1.5, 'Meningioma'),
#  Text(0, 2.5, 'None'),
#  Text(0, 3.5, 'Pituitary')]

# %%
model1.save('ranhypermodel1.h5') # saving the model
# best case model found on running random search several times had accuracy of 0.73 on the test set

# %%
#model1.summary() # model summary

# %%
# LeNet-5-type model with Bayesian Optimization

class LNhypermodel(HyperModel):
  def __init__(self, in_shape, num_classes):
    self.in_shape = in_shape
    self.num_classes = num_classes

  def build(self, hp):
    inputs = Input(shape=self.in_shape)
    for idx, i in enumerate(range(hp.Int('conv_layers', min_value=2, max_value=6, step=2))):
      if idx==0:
        x = inputs
      x = Conv2D(filters=hp.Int('filters'+str(i), min_value=8, max_value=128, step=32),
                 kernel_size=hp.Int('kernel_size', min_value=3, max_value=5, step=1),
                 padding='same')(x)
      x = LeakyReLU(0.1)(x)
      x = Dropout(hp.Float('dropout_1', min_value=0.0, max_value=0.4, step=0.2))(x)
      #x = MaxPool2D(pool_size=hp.Int('pool_size'+str(i), min_value=2, max_value=4, step=1), data_format='channels_last')(x)
      x = MaxPool2D(pool_size=2)(x)  # fix pool size
    x = Flatten()(x)
    for j in range(hp.Int('dense_layers', min_value=2, max_value=8, step=2)):
      x = Dense(hp.Int('units'+str(j), min_value=8, max_value=512, step=32))(x)
      x = LeakyReLU(0.1)(x)
      x = Dropout(hp.Float('dropout_2', min_value=0.0, max_value=0.6, step=0.2))(x)
    x = Dense(self.num_classes, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=x)
    model.compile(loss='categorical_crossentropy', 
                  optimizer=optimizers.Adam(lr=0.005), 
                  metrics=['accuracy'])
    return model

lnhmodel = LNhypermodel(in_shape=in_shape, num_classes=num_classes)
tuner_ln = BayesianOptimization(lnhmodel,
                                objective='val_accuracy',
                                max_trials=30,
                                executions_per_trial=5,
                                directory='.',
                                project_name='capstone_lenet')

tuner_ln.search(X_train, y_train_e, validation_split=0.2, shuffle=True, verbose=1, epochs=20)
# Out:
# Trial 5 Complete [00h 04m 18s]
# val_accuracy: 0.9525129914283752
#
# Best val_accuracy So Far: 0.9665511190891266
# Total elapsed time: 00h 15m 50s
# INFO:tensorflow:Oracle triggered exit

# %%
best_model_ln = tuner_ln.get_best_models(num_models=1)[0]
best_model_ln.evaluate(X_test, y_test_e)
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 13/13 [==============================] - 0s 6ms/step - loss: 254.1172 - accuracy: 0.0416
# [221.2398223876953, 0.1840796023607254]

# %%
# ResNet model with keras tuner and Hyperband optimization

from kerastuner.applications import HyperResNet
from kerastuner.tuners import Hyperband

hypermodel = HyperResNet(input_shape=in_shape, classes=num_classes)
tuner_rn = Hyperband(hypermodel,
                     objective='val_accuracy',
                     max_epochs=20,
                     hyperband_iterations=1,
                     directory='.',
                     project_name='capstone_resnet'
                    )
         
tuner_rn.search(X_train, y_train_e, validation_split=0.2)
# Out:
# Trial 30 Complete [00h 06m 01s]
# val_accuracy: 0.0
#
# Best val_accuracy So Far: 1.0
# Total elapsed time: 00h 57m 51s
# INFO:tensorflow:Oracle triggered exit

# %%
model_rn = tuner_rn.get_best_models(num_models=1)[0]
test_acc_model_rn = model_rn.evaluate(X_test, y_test_e)
# Out:
# 13/13 [==============================] - 4s 32ms/step - loss: 1.4965 - accuracy: 0.0416

# %% [markdown]
# ### Conclusions: ###
#
# Using Keras tuner did not improve accuracy for the test set, after trying different CNN architectures and ResNet, and with Random Search, Bayesian Optimization and Hyperband Optimization.
#
# These models provide high validation accuracy, but low test accuracy.

# %% [markdown]
# ## Autokeras ##

# %%
# AutoKeras

# !pip install autokeras
# Out:
# Requirement already satisfied: autokeras in /usr/local/lib/python3.6/dist-packages (1.0.12)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from autokeras) (0.22.2.post1)
# Requirement already satisfied: tensorflow>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from autokeras) (2.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from autokeras) (1.1.5)
# Requirement already satisfied: keras-tuner>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from autokeras) (1.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from autokeras) (20.8)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->autokeras) (1.0.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->autokeras) (1.19.5)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->autokeras) (1.4.1)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.3.0->autokeras) (3.7.4.3)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.3.0->autokeras) (1.1.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.3.0->autokeras) (1.12.1)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.3.0->autokeras) (0.10.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.3.0->autokeras) (0.36.2)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.3.0->autokeras) (3.3.0)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.3.0->autokeras) (0.3.3)
# Requirement already satisfied: grpcio~=1.32.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.3.0->autokeras) (1.32.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.3.0->autokeras) (1.6.3)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.3.0->autokeras) (0.2.0)
# Requirement already satisfied: h5py~=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.3.0->autokeras) (2.10.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.3.0->autokeras) (3.12.4)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0rc0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.3.0->autokeras) (2.4.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.3.0->autokeras) (1.12)
# Requirement already satisfied: tensorboard~=2.4 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.3.0->autokeras) (2.4.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.3.0->autokeras) (1.1.2)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.3.0->autokeras) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->autokeras) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->autokeras) (2018.9)
# Requirement already satisfied: terminaltables in /usr/local/lib/python3.6/dist-packages (from keras-tuner>=1.0.2->autokeras) (3.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from keras-tuner>=1.0.2->autokeras) (2.23.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from keras-tuner>=1.0.2->autokeras) (0.4.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from keras-tuner>=1.0.2->autokeras) (4.41.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from keras-tuner>=1.0.2->autokeras) (0.16.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from keras-tuner>=1.0.2->autokeras) (0.8.7)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->autokeras) (2.4.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.9.2->tensorflow>=2.3.0->autokeras) (51.1.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (3.3.3)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (1.17.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (0.4.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (1.7.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->keras-tuner>=1.0.2->autokeras) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->keras-tuner>=1.0.2->autokeras) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->keras-tuner>=1.0.2->autokeras) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->keras-tuner>=1.0.2->autokeras) (1.24.3)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (3.3.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (4.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (4.6)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (3.4.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=2.3.0->autokeras) (3.1.0)

# %%
# Autokeras

import autokeras as ak

clf = ak.ImageClassifier(max_trials=10)
clf.fit(X_train, y_train, epochs=10)

y_pred = clf.predict(X_test)

clf.evaluate(X_test, y_test)
# Out:
# INFO:tensorflow:Reloading Oracle from existing project ./image_classifier/oracle.json
# INFO:tensorflow:Reloading Tuner from ./image_classifier/tuner0.json
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.momentum
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.rho
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/10
# 91/91 [==============================] - 16s 111ms/step - loss: 1.8827 - accuracy: 0.7697
# Epoch 2/10
# 91/91 [==============================] - 10s 111ms/step - loss: 2.8045 - accuracy: 0.5917
# Epoch 3/10
# 91/91 [==============================] - 10s 111ms/step - loss: 4.0358 - accuracy: 0.6357
# Epoch 4/10
# 91/91 [==============================] - 10s 112ms/step - loss: 4.4772 - accuracy: 0.4545
# Epoch 5/10
# 91/91 [==============================] - 10s 111ms/step - loss: 3.9600 - accuracy: 0.5307
# Epoch 6/10
# 91/91 [==============================] - 10s 111ms/step - loss: 2.4735 - accuracy: 0.5578
# Epoch 7/10
# 91/91 [==============================] - 10s 111ms/step - loss: 1.9147 - accuracy: 0.1778
# Epoch 8/10
# 91/91 [==============================] - 10s 111ms/step - loss: 1.6953 - accuracy: 0.4119
# Epoch 9/10
# 91/91 [==============================] - 10s 111ms/step - loss: 2.1859 - accuracy: 0.3647
# Epoch 10/10
# 91/91 [==============================] - 10s 111ms/step - loss: 3.3127 - accuracy: 0.2856
# INFO:tensorflow:Assets written to: ./image_classifier/best_model/assets
# 13/13 [==============================] - 2s 39ms/step - loss: 1.8763 - accuracy: 0.1841
# [1.8763121366500854, 0.1840796023607254]

# %%
# Autokeras restricting the search to ResNet architectures

inputnode = ak.ImageInput()
outputnode = ak.ImageBlock(block_type="resnet")(inputnode)
outputnode = ak.ClassificationHead()(outputnode)
clf = ak.AutoModel(inputs=inputnode, outputs=outputnode, max_trials=10)
clf.fit(X_train, y_train, epochs=10)
clf.evaluate(X_test, y_test)
# Out:
# INFO:tensorflow:Reloading Oracle from existing project ./auto_model/oracle.json
# INFO:tensorflow:Reloading Tuner from ./auto_model/tuner0.json
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/10
# 91/91 [==============================] - 15s 111ms/step - loss: 3.5026 - accuracy: 0.7716
# Epoch 2/10
# 91/91 [==============================] - 10s 110ms/step - loss: 12.3390 - accuracy: 0.6710
# Epoch 3/10
# 91/91 [==============================] - 10s 110ms/step - loss: 4.3802 - accuracy: 0.7897
# Epoch 4/10
# 91/91 [==============================] - 10s 110ms/step - loss: 3.0489 - accuracy: 0.8025
# Epoch 5/10
# 91/91 [==============================] - 10s 111ms/step - loss: 3.2717 - accuracy: 0.8186
# Epoch 6/10
# 91/91 [==============================] - 10s 110ms/step - loss: 5.1453 - accuracy: 0.7519
# Epoch 7/10
# 91/91 [==============================] - 10s 110ms/step - loss: 4.7650 - accuracy: 0.7670
# Epoch 8/10
# 91/91 [==============================] - 10s 110ms/step - loss: 3.3470 - accuracy: 0.8038
# Epoch 9/10
# 91/91 [==============================] - 10s 111ms/step - loss: 6.7738 - accuracy: 0.7154
# Epoch 10/10
# 91/91 [==============================] - 10s 110ms/step - loss: 5.6726 - accuracy: 0.7462
# INFO:tensorflow:Assets written to: ./auto_model/best_model/assets
# 13/13 [==============================] - 2s 38ms/step - loss: 149.8979 - accuracy: 0.1841
# [149.89791870117188, 0.1840796023607254]

# %% [markdown]
# ### Conclusions: ###
#
# Autokeras, and restricting the search to ResNet architectures, was attempted, but did not perform well on the test set.

# %% [markdown]
# ## Transfer Learning ##
#
# Transfer learning will be tried with VGG-16.

# %%
# Generate the images with RGB channels

# Function to create image data sets
# Reading the images from the path and labeling them into the given categories, with RGB channels

def create_data_rgb(DATADIR):
    imgset = []
    classname = []
    for category in CATEGORIES:
        path = os.path.join(DATADIR,category)
        cat_name = CATEGORIES.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img))
                img_array = cv2.resize(img_array,(IMG_SIZE,IMG_SIZE)) 
                # normalize
                img_array = img_array/255.0
                # create image and category variables
                imgset.append(img_array)
                classname.append(cat_name)
            except:
                pass
    return np.array(imgset), np.array(classname)

# %%
# Training and test data with RGB channels
Xtrain_rgb, ytrain_rgb = create_data_rgb(TRAIN_DATADIR)
Xtest_rgb, ytest_rgb = create_data_rgb(TEST_DATADIR)

# %%
# Shapes
Xtrain_rgb.shape, ytrain_rgb.shape, Xtest_rgb.shape, ytest_rgb.shape
# Out:
# ((2881, 150, 150, 3), (2881,), (402, 150, 150, 3), (402,))

# %%
in_shape_rgb = Xtrain_rgb.shape[1:]   # input shape

# %%
# Transfer Learning with VGG16
from keras.applications import vgg16

# Define function to build model
def build_vggmodel(inshape):
  vgg = vgg16.VGG16(include_top=False, weights='imagenet', input_shape=inshape)
  output = vgg.layers[-1].output
  output = Flatten()(output)
  vgg_model = Model(vgg.input, output)

  # Uncomment these lines if the model is not to be trainable
  #vgg_model.trainable = False
  #for layer in vgg_model.layers:
  #  layer.trainable = False

  # Trainable for conv blocks 4 and 5 here
  vgg_model.trainable = True
  for layer in vgg_model.layers:
    if layer.name in ['block4_conv1', 'block5_conv1']:
      layer.trainable = True
    else:
      layer.trainable = False

  # Deep neural network classifier with 2 dense layers of 512 units and dropout, and final dense output layer
  inshape_vgg = vgg_model.output_shape[1]

  fmodel = Sequential() 
  fmodel.add(InputLayer(input_shape=inshape_vgg))
  fmodel.add(Dense(units=512, activation='relu', input_dim=inshape_vgg))
  fmodel.add(Dropout(0.3))
  fmodel.add(Dense(units=512, activation='relu'))
  fmodel.add(Dropout(0.3))
  fmodel.add(Dense(units=num_classes, activation='softmax'))
  # Compile model
  fmodel.compile(loss='categorical_crossentropy', optimizer=optimizers.Adam(lr=0.001), metrics=['accuracy'])
  return vggmodel, fmodel

# %%
# Extract bottleneck features and feed them to classifier

from sklearn.model_selection import train_test_split

def get_bottleneck_features(model, traindata):
  features = model.predict(traindata, verbose=0)
  return features

# train test split
X1, Xv, y1, yv = train_test_split(Xtrain_rgb, ytrain_rgb, test_size=0.2, random_state=42)
# one hot encoding of target variables
y1_enc = to_categorical(y1)
yv_enc = to_categorical(yv)
# Model (VGG model and classifier)
vgg_model, fmodel= build_vggmodel(inshape=in_shape_rgb)
# Extract features
train_features_vgg = get_bottleneck_features(vgg_model, X1)
val_features_vgg = get_bottleneck_features(vgg_model, Xv)
test_features_vgg = get_bottleneck_features(vgg_model, Xtest_rgb)

# %%
# Fit model to extracted features
history_fmodel = fmodel.fit(train_features_vgg, y1_enc, 
                            validation_data=(val_features_vgg, yv_enc),
                            batch_size=256,
                            epochs=20,
                            verbose=1)
# Out:
# Epoch 1/20
# 9/9 [==============================] - 0s 19ms/step - loss: 0.0490 - accuracy: 0.9839 - val_loss: 0.2580 - val_accuracy: 0.9185
# Epoch 2/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0465 - accuracy: 0.9883 - val_loss: 0.2924 - val_accuracy: 0.9099
# Epoch 3/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0393 - accuracy: 0.9874 - val_loss: 0.2319 - val_accuracy: 0.9307
# Epoch 4/20
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0309 - accuracy: 0.9944 - val_loss: 0.2427 - val_accuracy: 0.9272
# Epoch 5/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0239 - accuracy: 0.9952 - val_loss: 0.2518 - val_accuracy: 0.9237
# Epoch 6/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0258 - accuracy: 0.9935 - val_loss: 0.2647 - val_accuracy: 0.9133
# Epoch 7/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0232 - accuracy: 0.9926 - val_loss: 0.2660 - val_accuracy: 0.9272
# Epoch 8/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0167 - accuracy: 0.9965 - val_loss: 0.2637 - val_accuracy: 0.9289
# Epoch 9/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0123 - accuracy: 0.9970 - val_loss: 0.2618 - val_accuracy: 0.9272
# Epoch 10/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0230 - accuracy: 0.9935 - val_loss: 0.2963 - val_accuracy: 0.9168
# Epoch 11/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0227 - accuracy: 0.9939 - val_loss: 0.2644 - val_accuracy: 0.9237
# Epoch 12/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0134 - accuracy: 0.9983 - val_loss: 0.2899 - val_accuracy: 0.9203
# Epoch 13/20
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0147 - accuracy: 0.9952 - val_loss: 0.2644 - val_accuracy: 0.9255
# Epoch 14/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0112 - accuracy: 0.9974 - val_loss: 0.2722 - val_accuracy: 0.9203
# Epoch 15/20
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0117 - accuracy: 0.9970 - val_loss: 0.2868 - val_accuracy: 0.9237
# Epoch 16/20
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0128 - accuracy: 0.9970 - val_loss: 0.2863 - val_accuracy: 0.9272
# Epoch 17/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0096 - accuracy: 0.9987 - val_loss: 0.2876 - val_accuracy: 0.9307
# Epoch 18/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0076 - accuracy: 0.9996 - val_loss: 0.2745 - val_accuracy: 0.9341
# Epoch 19/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0066 - accuracy: 0.9987 - val_loss: 0.2961 - val_accuracy: 0.9203
# Epoch 20/20
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0094 - accuracy: 0.9978 - val_loss: 0.2496 - val_accuracy: 0.9272

# %%
# Test prediction
ypredvgg = fmodel.predict(test_features_vgg)
ypredvgg_classes = np.argmax(ypredvgg, axis=1)

# %%
# Test accuracy
accuracy_score(ytest_rgb, ypredvgg_classes)
# Out:
# 0.7313432835820896

# %%
# Classification report
print(classification_report(ytest_rgb, ypredvgg_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.23      0.36       100
#            1       0.65      0.96      0.77       115
#            2       0.73      0.96      0.83       113
#            3       0.93      0.72      0.81        74
#
#     accuracy                           0.73       402
#    macro avg       0.79      0.71      0.69       402
# weighted avg       0.77      0.73      0.69       402

# %%
# Confusion matrix
cf_matrix = confusion_matrix(ytest_rgb, ypredvgg_classes)
cf_matrix_n1 = cf_matrix/np.sum(cf_matrix, axis=1)
plt.figure(figsize=(8,6))
ax = sns.heatmap(cf_matrix_n1, xticklabels=CATEGORIES, yticklabels=CATEGORIES, annot=True)
ax.set_xticklabels(Cat_names)
ax.set_yticklabels(Cat_names)
# Out:
# [Text(0, 0.5, 'Glioma'),
#  Text(0, 1.5, 'Meningioma'),
#  Text(0, 2.5, 'None'),
#  Text(0, 3.5, 'Pituitary')]

# %% [markdown]
# ### Conclusions: ###
#
# Transfer learning with VGG-16 did not improve the accuracy of the test set prediction.

# %% [markdown]
# ## Combining the train and test sets, and splitting the  combined dataset into train, validation and test datasets ##

# %% [markdown]
# In the provided training and test images, there are differences in the glioma tumors between the training and test datasets. There are different types of gliomas, and they may be differently distributed in the training and test sets. As a result, the recall score for glioma was low in the test set, even though validation accuracy was high, on using the original training and test sets. To improve the prediction and build a better model, the training and test sets are combined here, and then split into a test set, validation set and training set. This results in an improved prediction.

# %%
from sklearn.model_selection import train_test_split

# Combine the train and test images provided
X_img = np.concatenate([X_train, X_test], axis=0)
y_classes = np.concatenate([y_train, y_test], axis=0)
# Split into new train and test set
Xtrn, Xtst, ytrn, ytst = train_test_split(X_img, y_classes, test_size=0.2, random_state=42)

# %%
# One hot encoding of target variables
ytrn_enc = to_categorical(ytrn)
ytst_enc = to_categorical(ytst)

# %%
# shape of new training and test datasets
Xtrn.shape, ytrn_enc.shape
# Out:
# ((2626, 150, 150, 1), (2626, 4))

# %%
Xtst.shape, ytst_enc.shape
# Out:
# ((657, 150, 150, 1), (657, 4))

# %%
# Attempt the fit with previously constructed model_cnn3

history_new_modelcnn_3 = model_cnn3.fit(Xtrn, ytrn_enc, validation_split=0.2, batch_size=512, verbose=1, epochs=40)
# Out:
# Epoch 1/40
# 5/5 [==============================] - 1s 137ms/step - loss: 2.2155 - accuracy: 0.2713 - val_loss: 1.4639 - val_accuracy: 0.3840
# Epoch 2/40
# 5/5 [==============================] - 0s 72ms/step - loss: 1.2983 - accuracy: 0.4233 - val_loss: 1.2983 - val_accuracy: 0.4011
# Epoch 3/40
# 5/5 [==============================] - 0s 70ms/step - loss: 1.2412 - accuracy: 0.4831 - val_loss: 1.2454 - val_accuracy: 0.4544
# Epoch 4/40
# 5/5 [==============================] - 0s 71ms/step - loss: 1.1830 - accuracy: 0.5159 - val_loss: 1.1633 - val_accuracy: 0.4981
# Epoch 5/40
# 5/5 [==============================] - 0s 68ms/step - loss: 1.1069 - accuracy: 0.5714 - val_loss: 1.1129 - val_accuracy: 0.5228
# Epoch 6/40
# 5/5 [==============================] - 0s 71ms/step - loss: 1.0102 - accuracy: 0.6050 - val_loss: 1.0500 - val_accuracy: 0.5285
# Epoch 7/40
# 5/5 [==============================] - 0s 68ms/step - loss: 0.9301 - accuracy: 0.6347 - val_loss: 0.9790 - val_accuracy: 0.6160
# Epoch 8/40
# 5/5 [==============================] - 0s 70ms/step - loss: 0.8586 - accuracy: 0.6650 - val_loss: 0.9693 - val_accuracy: 0.5551
# Epoch 9/40
# 5/5 [==============================] - 0s 70ms/step - loss: 0.8208 - accuracy: 0.6505 - val_loss: 0.9206 - val_accuracy: 0.5817
# Epoch 10/40
# 5/5 [==============================] - 0s 70ms/step - loss: 0.7773 - accuracy: 0.6930 - val_loss: 0.8951 - val_accuracy: 0.6046
# Epoch 11/40
# 5/5 [==============================] - 0s 70ms/step - loss: 0.7114 - accuracy: 0.7196 - val_loss: 0.8468 - val_accuracy: 0.6388
# Epoch 12/40
# 5/5 [==============================] - 0s 71ms/step - loss: 0.6852 - accuracy: 0.7497 - val_loss: 0.8123 - val_accuracy: 0.6616
ARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 5/5 [==============================] - 0s 106ms/step - loss: 0.1793 - accuracy: 0.9502 - val_loss: 0.5335 - val_accuracy: 0.8137
# Epoch 30/40
# 5/5 [==============================] - 0s 72ms/step - loss: 0.1580 - accuracy: 0.9590 - val_loss: 0.5979 - val_accuracy: 0.7909
# Epoch 31/40
# 5/5 [==============================] - 0s 70ms/step - loss: 0.1454 - accuracy: 0.9566 - val_loss: 0.5501 - val_accuracy: 0.8251
# Epoch 32/40
# 5/5 [==============================] - 0s 70ms/step - loss: 0.1276 - accuracy: 0.9726 - val_loss: 0.5616 - val_accuracy: 0.8118
# Epoch 33/40
# 5/5 [==============================] - 0s 69ms/step - loss: 0.1275 - accuracy: 0.9708 - val_loss: 0.6141 - val_accuracy: 0.8118
# Epoch 34/40
# 5/5 [==============================] - 0s 69ms/step - loss: 0.1280 - accuracy: 0.9724 - val_loss: 0.5726 - val_accuracy: 0.8118
# Epoch 35/40
# 5/5 [==============================] - 0s 71ms/step - loss: 0.1223 - accuracy: 0.9705 - val_loss: 0.5440 - val_accuracy: 0.8289
# Epoch 36/40
# 5/5 [==============================] - 0s 70ms/step - loss: 0.1073 - accuracy: 0.9779 - val_loss: 0.5333 - val_accuracy: 0.8270
# Epoch 37/40
# 5/5 [==============================] - 0s 73ms/step - loss: 0.0903 - accuracy: 0.9825 - val_loss: 0.5783 - val_accuracy: 0.8270
# Epoch 38/40
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0762 - accuracy: 0.9861 - val_loss: 0.5643 - val_accuracy: 0.8270
# Epoch 39/40
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0676 - accuracy: 0.9907 - val_loss: 0.5579 - val_accuracy: 0.8289
# Epoch 40/40
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0652 - accuracy: 0.9900 - val_loss: 0.5951 - val_accuracy: 0.8270

# %%
# Plot accuracy and loss
dict_hist_new_cnnmodel3 = history_new_modelcnn_3.history
iepoch = np.arange(1,41)
plot_acc(dict_hist_new_cnnmodel3, iepoch)

# %%
# Prediction on the test set
ytstpred_ncm3 = model_cnn3.predict(Xtst)
ytstcl_ncm3 = np.argmax(ytstpred_ncm3, axis=1)

# %%
accuracy_score(ytst, ytstcl_ncm3)
# Out:
# 0.8356164383561644

# %%
print(classification_report(ytst, ytstcl_ncm3, target_names=Cat_names))
# Out:
#               precision    recall  f1-score   support
#
#       Glioma       0.81      0.85      0.83       210
#   Meningioma       0.82      0.70      0.76       186
#         None       0.75      0.84      0.80        90
#    Pituitary       0.93      0.96      0.95       171
#
#     accuracy                           0.84       657
#    macro avg       0.83      0.84      0.83       657
# weighted avg       0.84      0.84      0.83       657

# %%
# Attempt the fit with previously constructed model_cnndo1

history_new_modelcnndo1 = model_cnndo1.fit(Xtrn, ytrn_enc, validation_split=0.2, verbose=1,epochs=40, batch_size=256)
# Out:
# Epoch 1/40
# 9/9 [==============================] - 3s 201ms/step - loss: 1.3887 - accuracy: 0.3776 - val_loss: 1.3560 - val_accuracy: 0.3080
# Epoch 2/40
# 9/9 [==============================] - 1s 144ms/step - loss: 1.2506 - accuracy: 0.4357 - val_loss: 1.3124 - val_accuracy: 0.3137
# Epoch 3/40
# 9/9 [==============================] - 1s 143ms/step - loss: 1.1715 - accuracy: 0.4881 - val_loss: 1.2522 - val_accuracy: 0.4867
# Epoch 4/40
# 9/9 [==============================] - 1s 144ms/step - loss: 1.0908 - accuracy: 0.5210 - val_loss: 1.2184 - val_accuracy: 0.4924
# Epoch 5/40
# 9/9 [==============================] - 1s 143ms/step - loss: 1.0079 - accuracy: 0.5819 - val_loss: 1.3025 - val_accuracy: 0.5000
# 9/9 [==============================] - 1s 145ms/step - loss: 0.1951 - accuracy: 0.9248 - val_loss: 1.2127 - val_accuracy: 0.7300
# Epoch 26/40
# 9/9 [==============================] - 1s 144ms/step - loss: 0.1847 - accuracy: 0.9195 - val_loss: 1.1459 - val_accuracy: 0.7567
# Epoch 27/40
# 9/9 [==============================] - 1s 144ms/step - loss: 0.1780 - accuracy: 0.9324 - val_loss: 1.7314 - val_accuracy: 0.6559
# Epoch 28/40
# 9/9 [==============================] - 1s 144ms/step - loss: 0.1735 - accuracy: 0.9257 - val_loss: 1.4719 - val_accuracy: 0.7110
# Epoch 29/40
# 9/9 [==============================] - 1s 145ms/step - loss: 0.1575 - accuracy: 0.9410 - val_loss: 1.5773 - val_accuracy: 0.6977
# Epoch 30/40
# 9/9 [==============================] - 1s 145ms/step - loss: 0.1593 - accuracy: 0.9448 - val_loss: 1.4390 - val_accuracy: 0.7053
# Epoch 31/40
# 9/9 [==============================] - 1s 144ms/step - loss: 0.1501 - accuracy: 0.9471 - val_loss: 1.5868 - val_accuracy: 0.7129
# Epoch 32/40
# 9/9 [==============================] - 1s 144ms/step - loss: 0.1410 - accuracy: 0.9410 - val_loss: 1.3398 - val_accuracy: 0.7243
# Epoch 33/40
# 9/9 [==============================] - 1s 144ms/step - loss: 0.1353 - accuracy: 0.9452 - val_loss: 1.4775 - val_accuracy: 0.7186
# Epoch 34/40
# 9/9 [==============================] - 1s 145ms/step - loss: 0.1153 - accuracy: 0.9533 - val_loss: 1.3357 - val_accuracy: 0.7643
# Epoch 35/40
# 9/9 [==============================] - 1s 145ms/step - loss: 0.1171 - accuracy: 0.9562 - val_loss: 1.7104 - val_accuracy: 0.7452
# Epoch 36/40
# 9/9 [==============================] - 1s 145ms/step - loss: 0.1278 - accuracy: 0.9519 - val_loss: 1.6495 - val_accuracy: 0.7357
# Epoch 37/40
# 9/9 [==============================] - 1s 143ms/step - loss: 0.1130 - accuracy: 0.9548 - val_loss: 1.4568 - val_accuracy: 0.7776
# Epoch 38/40
# 9/9 [==============================] - 1s 145ms/step - loss: 0.1030 - accuracy: 0.9581 - val_loss: 1.5275 - val_accuracy: 0.7757
# Epoch 39/40
# 9/9 [==============================] - 1s 144ms/step - loss: 0.1162 - accuracy: 0.9576 - val_loss: 1.4113 - val_accuracy: 0.7814
# Epoch 40/40
# 9/9 [==============================] - 1s 144ms/step - loss: 0.1037 - accuracy: 0.9610 - val_loss: 1.5568 - val_accuracy: 0.7586

# %%
# Plot accuracy and loss
dict_hist_new_cnndo1 = history_new_modelcnndo1.history
iepoch = np.arange(1,41)
plot_acc(dict_hist_new_cnndo1, iepoch)

# This model will not be used, due to low validation accuracy

# %%
# Attempt the fit with previously constructed model_ln3

# Early stopping
earlystop = EarlyStopping(monitor='val_loss', patience=3)
history_new_modelln3 = model_ln3.fit(Xtrn, ytrn_enc, validation_split=0.2, 
                                     verbose=1, epochs=40, batch_size=256,
                                     callbacks=[earlystop])
# Out:
# Epoch 1/40
# 9/9 [==============================] - 0s 47ms/step - loss: 0.0068 - accuracy: 0.9976 - val_loss: 0.6797 - val_accuracy: 0.8650
# Epoch 2/40
# 9/9 [==============================] - 0s 38ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.7277 - val_accuracy: 0.8555
# Epoch 3/40
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0077 - accuracy: 0.9976 - val_loss: 0.8432 - val_accuracy: 0.8289
# Epoch 4/40
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0125 - accuracy: 0.9957 - val_loss: 0.6920 - val_accuracy: 0.8574

# %%
# Plot accuracy and loss
dict_hist_new_ln3 = history_new_modelln3.history
iepoch = np.arange(1,5)
plot_acc(dict_hist_new_ln3, iepoch)

# %%
# Prediction on test set

ytstpred_nln3 = model_ln3.predict(Xtst)
ytstcl_nln3 = np.argmax(ytstpred_nln3, axis=1)

# %%
# Classification report
print(classification_report(ytst, ytstcl_nln3, target_names=Cat_names))
# Out:
#               precision    recall  f1-score   support
#
#       Glioma       0.89      0.92      0.90       210
#   Meningioma       0.91      0.83      0.87       186
#         None       0.85      0.89      0.87        90
#    Pituitary       0.96      0.98      0.97       171
#
#     accuracy                           0.91       657
#    macro avg       0.90      0.91      0.90       657
# weighted avg       0.91      0.91      0.91       657

# %%
# Confusion matrix
cf_matrix = confusion_matrix(ytst, ytstcl_nln3)
cf_matrix_n1 = cf_matrix/np.sum(cf_matrix, axis=1)
plt.figure(figsize=(8,6))
ax = sns.heatmap(cf_matrix_n1, xticklabels=CATEGORIES, yticklabels=CATEGORIES, annot=True)
ax.set_xticklabels(Cat_names)
ax.set_yticklabels(Cat_names)
# Out:
# [Text(0, 0.5, 'Glioma'),
#  Text(0, 1.5, 'Meningioma'),
#  Text(0, 2.5, 'None'),
#  Text(0, 3.5, 'Pituitary')]

# %% [markdown]
# The LeNet-5-type model works well, and provides an overall accuracy of 0.91 on the test set, and a recall of 0.92 for glioma.

# %% [markdown]
# Next, Keras Tuner will be attempted to improve the prediction.

# %% [markdown]
# ### Keras Tuner ###

# %% [markdown]
# Keras Tuner will be used for the previously constructed LeNet-5-type model, with Bayesian optimization.

# %%
tuner_ln_new = BayesianOptimization(lnhmodel,
                                    objective='val_accuracy',
                                    max_trials=20,
                                    executions_per_trial=5,
                                    directory='.',
                                    project_name='capstone_lenet_new')

tuner_ln_new.search(Xtrn, ytrn_enc, validation_split=0.2, shuffle=True, verbose=1, epochs=20)
# Out:
# Trial 20 Complete [00h 03m 30s]
# val_accuracy: 0.8087452411651611
#
# Best val_accuracy So Far: 0.8673003911972046
# Total elapsed time: 00h 53m 22s
# INFO:tensorflow:Oracle triggered exit

# %%
# Best model from Lenet-5-type architecture with keras tuner using Bayesian optimization
best_model_ln_new = tuner_ln_new.get_best_models(num_models=1)[0]
best_model_ln_new.evaluate(Xtst, ytst_enc)
# Out:
# 21/21 [==============================] - 0s 10ms/step - loss: 0.6191 - accuracy: 0.9165
# [0.6337112784385681, 0.9117199182510376]

# %%
# Test prediction
ypred_ktlnbo = best_model_ln_new.predict(Xtst)
ypredcl_ktlnbo = np.argmax(ypred_ktlnbo, axis=1)

# %%
# Classification report
print(classification_report(ytst, ypredcl_ktlnbo, target_names=Cat_names))
# Out:
#               precision    recall  f1-score   support
#
#       Glioma       0.95      0.87      0.91       210
#   Meningioma       0.88      0.88      0.88       186
#         None       0.80      0.94      0.87        90
#    Pituitary       0.97      0.98      0.97       171
#
#     accuracy                           0.91       657
#    macro avg       0.90      0.92      0.91       657
# weighted avg       0.92      0.91      0.91       657

# %%
# Confusion matrix
cf_matrix = confusion_matrix(ytst, ypredcl_ktlnbo)
cf_matrix_n1 = cf_matrix/np.sum(cf_matrix, axis=1)
plt.figure(figsize=(8,6))
ax = sns.heatmap(cf_matrix_n1, xticklabels=CATEGORIES, yticklabels=CATEGORIES, annot=True)
ax.set_xticklabels(Cat_names)
ax.set_yticklabels(Cat_names)
# Out:
# [Text(0, 0.5, 'Glioma'),
#  Text(0, 1.5, 'Meningioma'),
#  Text(0, 2.5, 'None'),
#  Text(0, 3.5, 'Pituitary')]

# %%
# Saving this model
best_model_ln_new.save("model_ktlnbo.h5")

# %%
best_model_ln_new.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 150, 150, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 150, 150, 8)       80
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 150, 150, 8)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 150, 150, 8)       0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 8)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 104)       7592
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 75, 75, 104)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 75, 75, 104)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 104)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 142376)            0
# _________________________________________________________________
# dense (Dense)                (None, 488)               69479976
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 488)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 488)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 488)               238632
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 488)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 488)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 1956
# =================================================================
# Total params: 69,728,236
# Trainable params: 69,728,236
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Next, the Keras Tuner for ResNet with Hyperband optimization is tried.

# %%
tuner_rn_new = Hyperband(hypermodel,
                         objective='val_accuracy',
                         max_epochs=20,
                         hyperband_iterations=1,
                         directory='.',
                         project_name='capstone_resnet_new'
                        )
          
tuner_rn_new.search(Xtrn, ytrn_enc, validation_split=0.2)
# Out:
# Trial 30 Complete [00h 02m 41s]
# val_accuracy: 0.8726235628128052
#
# Best val_accuracy So Far: 0.8726235628128052
# Total elapsed time: 00h 41m 49s
# INFO:tensorflow:Oracle triggered exit

# %%
# Best ResNet model
model_rn_new = tuner_rn_new.get_best_models(num_models=1)[0]
test_acc_model_rn_new = model_rn_new.evaluate(Xtst, ytst_enc)
# Out:
# 21/21 [==============================] - 4s 36ms/step - loss: 0.3031 - accuracy: 0.9096

# %%
# Test prediction
ypred_ktrn = model_rn_new.predict(Xtst)
ypred_ktrn_classes = np.argmax(ypred_ktrn, axis=1)

# %%
# classification report
print(classification_report(ytst, ypred_ktrn_classes, target_names=Cat_names))
# Out:
#               precision    recall  f1-score   support
#
#       Glioma       0.84      0.93      0.88       210
#   Meningioma       0.92      0.77      0.84       186
#         None       0.88      0.94      0.91        90
#    Pituitary       0.98      0.99      0.98       171
#
#     accuracy                           0.90       657
#    macro avg       0.91      0.91      0.90       657
# weighted avg       0.91      0.90      0.90       657

# %%
# Confusion matrix
cf_matrix = confusion_matrix(ytst, ypred_ktrn_classes)
cf_matrix_n1 = cf_matrix/np.sum(cf_matrix, axis=1)
plt.figure(figsize=(8,6))
ax = sns.heatmap(cf_matrix_n1, xticklabels=CATEGORIES, yticklabels=CATEGORIES, annot=True)
ax.set_xticklabels(Cat_names)
ax.set_yticklabels(Cat_names)
# Out:
# [Text(0, 0.5, 'Glioma'),
#  Text(0, 1.5, 'Meningioma'),
#  Text(0, 2.5, 'None'),
#  Text(0, 3.5, 'Pituitary')]

# %%
# saving this model
model_rn_new.save("model_ktrn.h5")

# %%
model_rn_new.summary()
# Out:
# Model: "ResNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 150, 150, 1) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 156, 156, 1)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 75, 75, 64)   3200        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 77, 77, 64)   0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 38, 38, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_bn (BatchNo (None, 38, 38, 64)   256         pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_relu (Activ (None, 38, 38, 64)   0           conv2_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 38, 38, 64)   4096        conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 38, 38, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 38, 38, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_pad (ZeroPadding (None, 40, 40, 64)   0           conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 38, 38, 64)   36864       conv2_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 38, 38, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 38, 38, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 38, 38, 256)  16640       conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 38, 38, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Add)          (None, 38, 38, 256)  0           conv2_block1_0_conv[0][0]
#                                                                  conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_bn (BatchNo (None, 38, 38, 256)  1024        conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_relu (Activ (None, 38, 38, 256)  0           conv2_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 38, 38, 64)   16384       conv2_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 38, 38, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 38, 38, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_pad (ZeroPadding (None, 40, 40, 64)   0           conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 38, 38, 64)   36864       conv2_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 38, 38, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 38, 38, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 38, 38, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Add)          (None, 38, 38, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_bn (BatchNo (None, 38, 38, 256)  1024        conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_relu (Activ (None, 38, 38, 256)  0           conv2_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 38, 38, 64)   16384       conv2_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 38, 38, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 38, 38, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_pad (ZeroPadding (None, 40, 40, 64)   0           conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 19, 19, 64)   36864       conv2_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 19, 19, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 19, 19, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 19, 19, 256)  0           conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 19, 19, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Add)          (None, 19, 19, 256)  0           max_pooling2d[0][0]
#                                                                  conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_bn (BatchNo (None, 19, 19, 256)  1024        conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_relu (Activ (None, 19, 19, 256)  0           conv3_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 19, 19, 128)  32768       conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 19, 19, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_pad (ZeroPadding (None, 21, 21, 128)  0           conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 19, 19, 128)  147456      conv3_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 19, 19, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 19, 19, 512)  131584      conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 19, 19, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Add)          (None, 19, 19, 512)  0           conv3_block1_0_conv[0][0]
#                                                                  conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_bn (BatchNo (None, 19, 19, 512)  2048        conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_relu (Activ (None, 19, 19, 512)  0           conv3_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 19, 19, 128)  65536       conv3_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 19, 19, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_pad (ZeroPadding (None, 21, 21, 128)  0           conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 19, 19, 128)  147456      conv3_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 19, 19, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 19, 19, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Add)          (None, 19, 19, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_bn (BatchNo (None, 19, 19, 512)  2048        conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_relu (Activ (None, 19, 19, 512)  0           conv3_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 19, 19, 128)  65536       conv3_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 19, 19, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_pad (ZeroPadding (None, 21, 21, 128)  0           conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 19, 19, 128)  147456      conv3_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 19, 19, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 19, 19, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Add)          (None, 19, 19, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_bn (BatchNo (None, 19, 19, 512)  2048        conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_relu (Activ (None, 19, 19, 512)  0           conv3_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 19, 19, 128)  65536       conv3_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 19, 19, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_pad (ZeroPadding (None, 21, 21, 128)  0           conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 10, 10, 128)  147456      conv3_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 10, 10, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 10, 10, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 10, 10, 512)  0           conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 10, 10, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Add)          (None, 10, 10, 512)  0           max_pooling2d_1[0][0]
#                                                                  conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_bn (BatchNo (None, 10, 10, 512)  2048        conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_relu (Activ (None, 10, 10, 512)  0           conv4_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 10, 10, 256)  131072      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 10, 10, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 10, 10, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 10, 10, 1024) 525312      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Add)          (None, 10, 10, 1024) 0           conv4_block1_0_conv[0][0]
#                                                                  conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_relu (Activ (None, 10, 10, 1024) 0           conv4_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 10, 10, 256)  262144      conv4_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 10, 10, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 10, 10, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Add)          (None, 10, 10, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_relu (Activ (None, 10, 10, 1024) 0           conv4_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 10, 10, 256)  262144      conv4_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 10, 10, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 10, 10, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Add)          (None, 10, 10, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_relu (Activ (None, 10, 10, 1024) 0           conv4_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 10, 10, 256)  262144      conv4_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 10, 10, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 10, 10, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Add)          (None, 10, 10, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_relu (Activ (None, 10, 10, 1024) 0           conv4_block5_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 10, 10, 256)  262144      conv4_block5_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 10, 10, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block5_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 10, 10, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Add)          (None, 10, 10, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_relu (Activ (None, 10, 10, 1024) 0           conv4_block6_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 10, 10, 256)  262144      conv4_block6_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 10, 10, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block6_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 10, 10, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Add)          (None, 10, 10, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv4_block7_preact_relu (Activ (None, 10, 10, 1024) 0           conv4_block7_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 10, 10, 256)  262144      conv4_block7_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 10, 10, 256)  0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block7_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_relu (Activation (None, 10, 10, 256)  0           conv4_block7_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block7_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_out (Add)          (None, 10, 10, 1024) 0           conv4_block6_out[0][0]
#                                                                  conv4_block7_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block7_out[0][0]
# __________________________________________________________________________________________________
# conv4_block8_preact_relu (Activ (None, 10, 10, 1024) 0           conv4_block8_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 10, 10, 256)  262144      conv4_block8_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 10, 10, 256)  0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block8_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_relu (Activation (None, 10, 10, 256)  0           conv4_block8_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block8_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_out (Add)          (None, 10, 10, 1024) 0           conv4_block7_out[0][0]
#                                                                  conv4_block8_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block8_out[0][0]
# __________________________________________________________________________________________________
# conv4_block9_preact_relu (Activ (None, 10, 10, 1024) 0           conv4_block9_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 10, 10, 256)  262144      conv4_block9_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 10, 10, 256)  0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block9_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_relu (Activation (None, 10, 10, 256)  0           conv4_block9_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block9_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_out (Add)          (None, 10, 10, 1024) 0           conv4_block8_out[0][0]
#                                                                  conv4_block9_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_preact_bn (BatchN (None, 10, 10, 1024) 4096        conv4_block9_out[0][0]
# __________________________________________________________________________________________________
# conv4_block10_preact_relu (Acti (None, 10, 10, 1024) 0           conv4_block10_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 10, 10, 256)  262144      conv4_block10_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 10, 10, 256)  1024        conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 10, 10, 256)  0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_pad (ZeroPaddin (None, 12, 12, 256)  0           conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 10, 10, 256)  589824      conv4_block10_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_bn (BatchNormal (None, 10, 10, 256)  1024        conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_relu (Activatio (None, 10, 10, 256)  0           conv4_block10_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_3_conv (Conv2D)   (None, 10, 10, 1024) 263168      conv4_block10_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_out (Add)         (None, 10, 10, 1024) 0           conv4_block9_out[0][0]
#                                                                  conv4_block10_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_preact_bn (BatchN (None, 10, 10, 1024) 4096        conv4_block10_out[0][0]
# __________________________________________________________________________________________________
# conv4_block11_preact_relu (Acti (None, 10, 10, 1024) 0           conv4_block11_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 10, 10, 256)  262144      conv4_block11_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 10, 10, 256)  1024        conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 10, 10, 256)  0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_pad (ZeroPaddin (None, 12, 12, 256)  0           conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 10, 10, 256)  589824      conv4_block11_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_bn (BatchNormal (None, 10, 10, 256)  1024        conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_relu (Activatio (None, 10, 10, 256)  0           conv4_block11_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_3_conv (Conv2D)   (None, 10, 10, 1024) 263168      conv4_block11_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_out (Add)         (None, 10, 10, 1024) 0           conv4_block10_out[0][0]
#                                                                  conv4_block11_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_preact_bn (BatchN (None, 10, 10, 1024) 4096        conv4_block11_out[0][0]
# __________________________________________________________________________________________________
# conv4_block12_preact_relu (Acti (None, 10, 10, 1024) 0           conv4_block12_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 10, 10, 256)  262144      conv4_block12_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 10, 10, 256)  1024        conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 10, 10, 256)  0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_pad (ZeroPaddin (None, 12, 12, 256)  0           conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 10, 10, 256)  589824      conv4_block12_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_bn (BatchNormal (None, 10, 10, 256)  1024        conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_relu (Activatio (None, 10, 10, 256)  0           conv4_block12_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_3_conv (Conv2D)   (None, 10, 10, 1024) 263168      conv4_block12_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_out (Add)         (None, 10, 10, 1024) 0           conv4_block11_out[0][0]
#                                                                  conv4_block12_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_preact_bn (BatchN (None, 10, 10, 1024) 4096        conv4_block12_out[0][0]
# __________________________________________________________________________________________________
# conv4_block13_preact_relu (Acti (None, 10, 10, 1024) 0           conv4_block13_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_conv (Conv2D)   (None, 10, 10, 256)  262144      conv4_block13_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_bn (BatchNormal (None, 10, 10, 256)  1024        conv4_block13_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_relu (Activatio (None, 10, 10, 256)  0           conv4_block13_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_pad (ZeroPaddin (None, 12, 12, 256)  0           conv4_block13_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_conv (Conv2D)   (None, 10, 10, 256)  589824      conv4_block13_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_bn (BatchNormal (None, 10, 10, 256)  1024        conv4_block13_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_relu (Activatio (None, 10, 10, 256)  0           conv4_block13_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_3_conv (Conv2D)   (None, 10, 10, 1024) 263168      conv4_block13_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_out (Add)         (None, 10, 10, 1024) 0           conv4_block12_out[0][0]
#                                                                  conv4_block13_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_preact_bn (BatchN (None, 10, 10, 1024) 4096        conv4_block13_out[0][0]
# ...
# conv4_block20_2_bn (BatchNormal (None, 10, 10, 256)  1024        conv4_block20_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block20_2_relu (Activatio (None, 10, 10, 256)  0           conv4_block20_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block20_3_conv (Conv2D)   (None, 10, 10, 1024) 263168      conv4_block20_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block20_out (Add)         (None, 10, 10, 1024) 0           conv4_block19_out[0][0]
#                                                                  conv4_block20_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block21_preact_bn (BatchN (None, 10, 10, 1024) 4096        conv4_block20_out[0][0]
# __________________________________________________________________________________________________
# conv4_block21_preact_relu (Acti (None, 10, 10, 1024) 0           conv4_block21_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block21_1_conv (Conv2D)   (None, 10, 10, 256)  262144      conv4_block21_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block21_1_bn (BatchNormal (None, 10, 10, 256)  1024        conv4_block21_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block21_1_relu (Activatio (None, 10, 10, 256)  0           conv4_block21_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block21_2_pad (ZeroPaddin (None, 12, 12, 256)  0           conv4_block21_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block21_2_conv (Conv2D)   (None, 10, 10, 256)  589824      conv4_block21_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block21_2_bn (BatchNormal (None, 10, 10, 256)  1024        conv4_block21_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block21_2_relu (Activatio (None, 10, 10, 256)  0           conv4_block21_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block21_3_conv (Conv2D)   (None, 10, 10, 1024) 263168      conv4_block21_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block21_out (Add)         (None, 10, 10, 1024) 0           conv4_block20_out[0][0]
#                                                                  conv4_block21_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_preact_bn (BatchN (None, 10, 10, 1024) 4096        conv4_block21_out[0][0]
# __________________________________________________________________________________________________
# conv4_block22_preact_relu (Acti (None, 10, 10, 1024) 0           conv4_block22_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_conv (Conv2D)   (None, 10, 10, 256)  262144      conv4_block22_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_bn (BatchNormal (None, 10, 10, 256)  1024        conv4_block22_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_relu (Activatio (None, 10, 10, 256)  0           conv4_block22_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_pad (ZeroPaddin (None, 12, 12, 256)  0           conv4_block22_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_conv (Conv2D)   (None, 10, 10, 256)  589824      conv4_block22_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_bn (BatchNormal (None, 10, 10, 256)  1024        conv4_block22_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_relu (Activatio (None, 10, 10, 256)  0           conv4_block22_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_3_conv (Conv2D)   (None, 10, 10, 1024) 263168      conv4_block22_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block22_out (Add)         (None, 10, 10, 1024) 0           conv4_block21_out[0][0]
#                                                                  conv4_block22_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_preact_bn (BatchN (None, 10, 10, 1024) 4096        conv4_block22_out[0][0]
# __________________________________________________________________________________________________
# conv4_block23_preact_relu (Acti (None, 10, 10, 1024) 0           conv4_block23_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_conv (Conv2D)   (None, 10, 10, 256)  262144      conv4_block23_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_bn (BatchNormal (None, 10, 10, 256)  1024        conv4_block23_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_relu (Activatio (None, 10, 10, 256)  0           conv4_block23_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_pad (ZeroPaddin (None, 12, 12, 256)  0           conv4_block23_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_conv (Conv2D)   (None, 5, 5, 256)    589824      conv4_block23_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_bn (BatchNormal (None, 5, 5, 256)    1024        conv4_block23_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_relu (Activatio (None, 5, 5, 256)    0           conv4_block23_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 5, 5, 1024)   0           conv4_block22_out[0][0]
# __________________________________________________________________________________________________
# conv4_block23_3_conv (Conv2D)   (None, 5, 5, 1024)   263168      conv4_block23_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block23_out (Add)         (None, 5, 5, 1024)   0           max_pooling2d_2[0][0]
#                                                                  conv4_block23_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_bn (BatchNo (None, 5, 5, 1024)   4096        conv4_block23_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_relu (Activ (None, 5, 5, 1024)   0           conv5_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 5, 5, 512)    524288      conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 5, 5, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_pad (ZeroPadding (None, 7, 7, 512)    0           conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 5, 5, 512)    2359296     conv5_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 5, 5, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 5, 5, 2048)   2099200     conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 5, 5, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Add)          (None, 5, 5, 2048)   0           conv5_block1_0_conv[0][0]
#                                                                  conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_bn (BatchNo (None, 5, 5, 2048)   8192        conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_relu (Activ (None, 5, 5, 2048)   0           conv5_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 5, 5, 512)    1048576     conv5_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 5, 5, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_pad (ZeroPadding (None, 7, 7, 512)    0           conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 5, 5, 512)    2359296     conv5_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 5, 5, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 5, 5, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Add)          (None, 5, 5, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_bn (BatchNo (None, 5, 5, 2048)   8192        conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_relu (Activ (None, 5, 5, 2048)   0           conv5_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 5, 5, 512)    1048576     conv5_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 5, 5, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_pad (ZeroPadding (None, 7, 7, 512)    0           conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 5, 5, 512)    2359296     conv5_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 5, 5, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 5, 5, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Add)          (None, 5, 5, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# post_bn (BatchNormalization)    (None, 5, 5, 2048)   8192        conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# post_relu (Activation)          (None, 5, 5, 2048)   0           post_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           post_relu[0][0]
# __________________________________________________________________________________________________
# probs (Dense)                   (None, 4)            8196        avg_pool[0][0]
# ==================================================================================================
# Total params: 42,628,484
# Trainable params: 42,530,820
# Non-trainable params: 97,664
# __________________________________________________________________________________________________

# %% [markdown]
# ### Conclusions: ###
# The ResNet model provided the highest recall of 0.93 for glioma.

# %% [markdown]
# ### Transfer learning with VGG-16 ###
#
# Transfer learning with VGG-16 is tried here.

# %%
# Combine training and test sets with RGB channels, and split into new training, validation and test sets

Ximg_rgb = np.concatenate([Xtrain_rgb, Xtest_rgb], axis=0)
yclasses_fin = np.concatenate([ytrain_rgb, ytest_rgb], axis=0)

# training and test split
X1_new, Xtst_new, y1_new, ytst_new = train_test_split(Ximg_rgb, yclasses_fin, test_size=0.2, 
                                                      random_state=42)
# training and validation split
Xt_new, Xv_new, yt_new, yv_new = train_test_split(X1_new, y1_new, test_size=0.2, 
                                                  random_state=42)

# one hot encoding of target variables
yt_new_enc = to_categorical(yt_new)
yv_new_enc = to_categorical(yv_new)
# Model
vgg_model, fmodel_new = build_vggmodel(inshape=Xt_new.shape[1:])
# Extract features
train_features_vgg_new = get_bottleneck_features(vgg_model, Xt_new)
val_features_vgg_new = get_bottleneck_features(vgg_model, Xv_new)
test_features_vgg_new = get_bottleneck_features(vgg_model, Xtst_new)

# %%
# Fit model to extracted features
history_fmodel_new = fmodel_new.fit(train_features_vgg_new, yt_new_enc, 
                                    validation_data=(val_features_vgg_new, yv_new_enc),
                                    batch_size=256,
                                    epochs=20,
                                    verbose=1)
# Out:
# Epoch 1/20
# 9/9 [==============================] - 1s 32ms/step - loss: 2.3672 - accuracy: 0.2899 - val_loss: 1.1541 - val_accuracy: 0.4601
# Epoch 2/20
# 9/9 [==============================] - 0s 13ms/step - loss: 1.1550 - accuracy: 0.5042 - val_loss: 0.8354 - val_accuracy: 0.6597
# Epoch 3/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.8493 - accuracy: 0.6364 - val_loss: 0.6853 - val_accuracy: 0.7224
# Epoch 4/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.6846 - accuracy: 0.7225 - val_loss: 0.6156 - val_accuracy: 0.7452
# Epoch 5/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.5717 - accuracy: 0.7801 - val_loss: 0.5403 - val_accuracy: 0.7871
# Epoch 6/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.5041 - accuracy: 0.7991 - val_loss: 0.5024 - val_accuracy: 0.8099
# Epoch 7/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.4254 - accuracy: 0.8360 - val_loss: 0.4480 - val_accuracy: 0.8270
# Epoch 8/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3579 - accuracy: 0.8619 - val_loss: 0.4198 - val_accuracy: 0.8460
# Epoch 9/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3256 - accuracy: 0.8913 - val_loss: 0.3924 - val_accuracy: 0.8460
# Epoch 10/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2935 - accuracy: 0.8950 - val_loss: 0.3845 - val_accuracy: 0.8612
# Epoch 11/20
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2482 - accuracy: 0.9155 - val_loss: 0.4289 - val_accuracy: 0.8517
# Epoch 12/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2852 - accuracy: 0.8895 - val_loss: 0.3344 - val_accuracy: 0.8707
# Epoch 13/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2075 - accuracy: 0.9270 - val_loss: 0.3406 - val_accuracy: 0.8650
# Epoch 14/20
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1815 - accuracy: 0.9369 - val_loss: 0.3123 - val_accuracy: 0.8916
# Epoch 15/20
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1739 - accuracy: 0.9429 - val_loss: 0.3015 - val_accuracy: 0.8916
# Epoch 16/20
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1430 - accuracy: 0.9489 - val_loss: 0.3467 - val_accuracy: 0.8878
# Epoch 17/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1235 - accuracy: 0.9631 - val_loss: 0.2973 - val_accuracy: 0.8992
# Epoch 18/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1048 - accuracy: 0.9652 - val_loss: 0.4018 - val_accuracy: 0.8859
# Epoch 19/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1113 - accuracy: 0.9591 - val_loss: 0.2690 - val_accuracy: 0.9049
# Epoch 20/20
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0839 - accuracy: 0.9731 - val_loss: 0.3042 - val_accuracy: 0.9068

# %%
# Test prediction
ypred_vgg_new = fmodel_new.predict(test_features_vgg_new)
ypred_vgg_new_classes = np.argmax(ypred_vgg_new, axis=1)

# %%
# Classification report
print(classification_report(ytst_new, ypred_vgg_new_classes, target_names=Cat_names))
# Out:
#               precision    recall  f1-score   support
#
#       Glioma       0.92      0.88      0.90       210
#   Meningioma       0.85      0.91      0.88       186
#         None       0.98      0.93      0.95        90
#    Pituitary       0.98      0.97      0.98       171
#
#     accuracy                           0.92       657
#    macro avg       0.93      0.92      0.93       657
# weighted avg       0.92      0.92      0.92       657

# %%
# Confusion matrix
cf_matrix = confusion_matrix(ytst, ypred_vgg_new_classes)
cf_matrix_n1 = cf_matrix/np.sum(cf_matrix, axis=1)
plt.figure(figsize=(8,6))
ax = sns.heatmap(cf_matrix_n1, xticklabels=CATEGORIES, yticklabels=CATEGORIES, annot=True)
ax.set_xticklabels(Cat_names)
ax.set_yticklabels(Cat_names)
# Out:
# [Text(0, 0.5, 'Glioma'),
#  Text(0, 1.5, 'Meningioma'),
#  Text(0, 2.5, 'None'),
#  Text(0, 3.5, 'Pituitary')]

# %% [markdown]
# ## Conclusions: ###
# * Using the original training and test data sets, a maximum accuracy of 0.77 on the test set could be obtained, with a low recall of 0.22 for glioma. However, the validation accuracy is very high. This is caused by the difference in the types of glioma images in the training and test sets.
# * Keras tuner with LeNet-5 and ResNet architectures, and AutoKeras with vanilla and ResNet architectures were attempted, but did not improve accuracy on the test set.
# * When the training and test sets originally provided were combined and then split into train, validation and test sets, the prediction could be improved.
# * The recall for glioma in the test set improved to 0.92-0.93, and the overall accuracy on the test set exceeded 0.9.
